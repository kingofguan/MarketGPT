# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Note: I used this notebook to get acclimated with the ABIDES exchange agent and order books and validate the matching engine with empirical data

# %%
import os
import sys

(parent_folder_path, current_dir) = os.path.split(os.path.abspath(''))
sys.path.append(parent_folder_path)
sys.path.append(os.path.join(parent_folder_path, 'simulator'))
sys.path.append(os.path.join(parent_folder_path, 'equities/data_processing'))

# os.environ["XLA_PYTHON_CLIENT_ALLOCATOR"] = "platform"

import numpy as np
import pandas as pd
import random
from typing import List, Tuple
from copy import deepcopy
from tqdm import tqdm
from glob import glob
from decimal import Decimal

from simulator.core import Message
from simulator.markets.order_book import OrderBook
from simulator.markets.orders import LimitOrder, Side, MarketOrder
from equities.data_processing import itch_preproc
from equities.data_processing import itch_encoding

# %%
SYMBOL = "X"
TIME = 0


class FakeExchangeAgent:
    def __init__(self):
        self.messages = []
        self.current_time = TIME
        self.mkt_open = TIME
        self.book_logging = None
        self.stream_history = 10

    def reset(self):
        self.messages = []

    def send_message(self, recipient_id: int, message: Message, _: int = 0):
        self.messages.append((recipient_id, message))

    def logEvent(self, *args, **kwargs):
        pass


def setup_book_with_orders(
    bids: List[Tuple[int, List[int]]] = [], asks: List[Tuple[int, List[int]]] = []
) -> Tuple[OrderBook, FakeExchangeAgent, List[LimitOrder]]:
    agent = FakeExchangeAgent()
    book = OrderBook(agent, SYMBOL)
    orders = []

    for price, quantities in bids:
        for quantity in quantities:
            order = LimitOrder(1, TIME, SYMBOL, quantity, Side.BID, price)
            book.handle_limit_order(order)
            orders.append(order)

    for price, quantities in asks:
        for quantity in quantities:
            order = LimitOrder(1, TIME, SYMBOL, quantity, Side.ASK, price)
            book.handle_limit_order(order)
            orders.append(order)

    agent.reset()

    return book, agent, orders

# %% [markdown]
# ### Exploring book methods

# %%
book, agent, orders = setup_book_with_orders(
    bids=[
        (100, [40, 10]),
        (200, [10, 30, 20, 10]),
    ],
    asks=[
        (300, [10, 50, 20]),
        (400, [40, 10]),
        (500, [20]),
    ],
)

# %%
vars(book)
# Out:
# {'owner': <__main__.FakeExchangeAgent at 0x7f3e3c94bb60>,
#  'symbol': 'X',
#  'bids': [<simulator.markets.price_level.PriceLevel at 0x7f3e3c92eae0>,
#   <simulator.markets.price_level.PriceLevel at 0x7f3e3c9497c0>],
#  'asks': [<simulator.markets.price_level.PriceLevel at 0x7f3e3c92de50>,
#   <simulator.markets.price_level.PriceLevel at 0x7f3e3c92ffe0>,
#   <simulator.markets.price_level.PriceLevel at 0x7f3e3c92ff50>],
#  'last_trade': None,
#  'book_log2': [],
#  'quotes_seen': set(),
#  'history': [{'time': 0,
#    'type': 'LIMIT',
#    'order_id': 0,
#    'agent_id': 1,
#    'side': 'BID',
#    'quantity': 40,
#    'price': 100},
#   {'time': 0,
#    'type': 'LIMIT',
#    'order_id': 1,
#    'agent_id': 1,
#    'side': 'BID',
#    'quantity': 10,
#    'price': 100},
#   {'time': 0,
#    'type': 'LIMIT',
#    'order_id': 2,
#    'agent_id': 1,
#    'side': 'BID',
#    'quantity': 10,
#    'price': 200},
#   {'time': 0,
#    'type': 'LIMIT',
#    'order_id': 3,
#    'agent_id': 1,
#    'side': 'BID',
#    'quantity': 30,
#    'price': 200},
#   {'time': 0,
#    'type': 'LIMIT',
#    'order_id': 4,
#    'agent_id': 1,
#    'side': 'BID',
#    'quantity': 20,
#    'price': 200},
#   {'time': 0,
#    'type': 'LIMIT',
#    'order_id': 5,
#    'agent_id': 1,
#    'side': 'BID',
#    'quantity': 10,
#    'price': 200},
#   {'time': 0,
#    'type': 'LIMIT',
#    'order_id': 6,
#    'agent_id': 1,
#    'side': 'ASK',
#    'quantity': 10,
#    'price': 300},
#   {'time': 0,
#    'type': 'LIMIT',
#    'order_id': 7,
#    'agent_id': 1,
#    'side': 'ASK',
#    'quantity': 50,
#    'price': 300},
#   {'time': 0,
#    'type': 'LIMIT',
#    'order_id': 8,
#    'agent_id': 1,
#    'side': 'ASK',
#    'quantity': 20,
#    'price': 300},
#   {'time': 0,
#    'type': 'LIMIT',
#    'order_id': 9,
#    'agent_id': 1,
#    'side': 'ASK',
#    'quantity': 40,
#    'price': 400},
#   {'time': 0,
#    'type': 'LIMIT',
#    'order_id': 10,
#    'agent_id': 1,
#    'side': 'ASK',
#    'quantity': 10,
#    'price': 400},
#   {'time': 0,
#    'type': 'LIMIT',
#    'order_id': 11,
#    'agent_id': 1,
#    'side': 'ASK',
#    'quantity': 20,
#    'price': 500}],
#  'last_update_ts': 0,
#  'buy_transactions': [],
#  'sell_transactions': []}

# %%
vars(agent)
# Out:
# {'messages': [],
#  'current_time': 0,
#  'mkt_open': 0,
#  'book_logging': None,
#  'stream_history': 10}

# %%
# ordered by end of bid side book to end of ask side book
orders
# Out:
# [(Agent 1 @ 1970-01-01 00:00:00) : BID 40 X @ $1.00,
#  (Agent 1 @ 1970-01-01 00:00:00) : BID 10 X @ $1.00,
#  (Agent 1 @ 1970-01-01 00:00:00) : BID 10 X @ $2.00,
#  (Agent 1 @ 1970-01-01 00:00:00) : BID 30 X @ $2.00,
#  (Agent 1 @ 1970-01-01 00:00:00) : BID 20 X @ $2.00,
#  (Agent 1 @ 1970-01-01 00:00:00) : BID 10 X @ $2.00,
#  (Agent 1 @ 1970-01-01 00:00:00) : ASK 10 X @ $3.00,
#  (Agent 1 @ 1970-01-01 00:00:00) : ASK 50 X @ $3.00,
#  (Agent 1 @ 1970-01-01 00:00:00) : ASK 20 X @ $3.00,
#  (Agent 1 @ 1970-01-01 00:00:00) : ASK 40 X @ $4.00,
#  (Agent 1 @ 1970-01-01 00:00:00) : ASK 10 X @ $4.00,
#  (Agent 1 @ 1970-01-01 00:00:00) : ASK 20 X @ $5.00]

# %%
print(orders[1])
print(book.get_l3_bid_data())

# Cancel bid order, mid book
book.cancel_order(orders[1])
print(book.get_l3_bid_data())

agent.messages
# Out:
# (Agent 1 @ 1970-01-01 00:00:00) : BID 10 X @ $1.00
# [(200, [10, 30, 20, 10]), (100, [40, 10])]
# [(200, [10, 30, 20, 10]), (100, [40])]
# [(1,
#   OrderCancelledMsg(message_id=39, order=(Agent 1 @ 1970-01-01 00:00:00) : BID 10 X @ $1.00))]

# %%
print("L1 bid data:", book.get_l1_bid_data()) # best bid tuple (price, volume)
print("L1 ask data:", book.get_l1_ask_data()) # best ask tuple (price, volume)
print("L2 bid data:", book.get_l2_bid_data()) # entire bid side
print("L2 ask data:", book.get_l2_ask_data()) # entire ask side
print("L3 bid data:", book.get_l3_bid_data()) # full order view bid side
print("L3 ask data:", book.get_l3_ask_data()) # full order view ask side

print("transacted volume", book.get_transacted_volume()) # tuple (bid, ask)
print("order book imbalance", book.get_imbalance()) # tuple (volume imbalance value, side that has more volume)
# Out:
# L1 bid data: (200, 70)
# L1 ask data: (300, 80)
# L2 bid data: [(200, 70), (100, 40)]
# L2 ask data: [(300, 80), (400, 50), (500, 20)]
# L3 bid data: [(200, [10, 30, 20, 10]), (100, [40])]
# L3 ask data: [(300, [10, 50, 20]), (400, [40, 10]), (500, [20])]
# transacted volume (0, 0)
# order book imbalance (0.2666666666666667, <Side.ASK: 'ASK'>)

# %%
# init new book under nasdaq agent
agent = FakeExchangeAgent()
book = OrderBook(agent, SYMBOL)
assert book.bids == book.asks == [] # empty book

# insert bid order
bid_order = LimitOrder(
    agent_id=1,
    time_placed=TIME,
    symbol=SYMBOL,
    quantity=10,
    side=Side.BID,
    limit_price=100,
)
book.handle_limit_order(bid_order)

# insert another bid order with id specified
order2 = LimitOrder(
    order_id=69,
    agent_id=1,
    time_placed=TIME,
    symbol=SYMBOL,
    quantity=20,
    side=Side.BID,
    limit_price=100,
)
book.handle_limit_order(order2)

# insert ask order
ask_order = LimitOrder(
    agent_id=1,
    time_placed=TIME,
    symbol=SYMBOL,
    quantity=20,
    side=Side.ASK,
    limit_price=110,
)
book.handle_limit_order(ask_order)

print("L3 bid data:", book.get_l3_bid_data())
print("L3 ask data:", book.get_l3_ask_data())

print("bid_order.order_id:", agent.messages[0][1].order.order_id)
print("order2.order_id:", agent.messages[1][1].order.order_id)
print("ask_order.order_id:", agent.messages[2][1].order.order_id)
# Out:
# L3 bid data: [(100, [10, 20])]
# L3 ask data: [(110, [20])]
# bid_order.order_id: 6
# order2.order_id: 69
# ask_order.order_id: 7

# %%
# send buy order that partially consumes one order
market_order = MarketOrder(
    agent_id=2,
    time_placed=TIME,
    symbol=SYMBOL,
    quantity=10,
    side=Side.BID,
)
book.handle_market_order(market_order)

print("L3 bid data:", book.get_l3_bid_data())
print("L3 ask data:", book.get_l3_ask_data())
print("transacted volume", book.get_transacted_volume()) # tuple (buy, sell)
# Out:
# L3 bid data: [(100, [10, 20])]
# L3 ask data: [(110, [10])]
# transacted volume (10, 0)

# %%
# Modify order quantity down from 10 to 30
modified_order = deepcopy(bid_order)
modified_order.quantity = 30

book.modify_order(bid_order, modified_order)
print("L3 bid data:", book.get_l3_bid_data()) # order priority is changed
print("L3 ask data:", book.get_l3_ask_data())
# Out:
# L3 bid data: [(100, [20, 30])]
# L3 ask data: [(110, [10])]

# %%
# place price-to-comply order and then cancel it
order = LimitOrder(
    agent_id=1,
    time_placed=TIME,
    symbol=SYMBOL,
    quantity=10,
    side=Side.BID,
    is_price_to_comply=True,
    limit_price=100,
)
book.handle_limit_order(order)
print("(pre-cancel) L3 bid data:", book.get_l3_bid_data())
print("(pre-cancel) L3 ask data:", book.get_l3_ask_data())

book.cancel_order(order)
print("(post-cancel) L3 bid data:", book.get_l3_bid_data())
print("(post-cancel) L3 ask data:", book.get_l3_ask_data())
# Out:
# (pre-cancel) L3 bid data: [(101, []), (100, [20, 30, 10])]
# (pre-cancel) L3 ask data: [(110, [10])]
# (post-cancel) L3 bid data: [(100, [20, 30])]
# (post-cancel) L3 ask data: [(110, [10])]

# %%
# place price-to-comply order and then fill it
order = LimitOrder(
    agent_id=1,
    time_placed=TIME,
    symbol=SYMBOL,
    quantity=10,
    side=Side.ASK,
    is_price_to_comply=True,
    limit_price=110,
)
book.handle_limit_order(order)
print("L3 bid data:", book.get_l3_bid_data())
print("L3 ask data:", book.get_l3_ask_data())

market_order = MarketOrder(
    agent_id=1,
    time_placed=TIME,
    symbol=SYMBOL,
    quantity=10,
    side=Side.BID,
)
book.handle_market_order(market_order)
print("L3 bid data:", book.get_l3_bid_data())
print("L3 ask data:", book.get_l3_ask_data())
# Out:
# L3 bid data: [(100, [20, 30])]
# L3 ask data: [(109, []), (110, [10, 10])]
# L3 bid data: [(100, [20, 30])]
# L3 ask data: [(110, [10])]

# %%
# confirm that the order was executed as intended
agent.messages[-1][1].order.fill_price
print("The order was executed at the inside-ask price:", agent.messages[-1][1].order.fill_price)
# Out:
# The order was executed at the inside-ask price: 109

# %%
# Replace 10 @ $110 with 50 @ $111, ask side of book
new_ask_order = LimitOrder(
    agent_id=1,
    time_placed=TIME,
    symbol=SYMBOL,
    quantity=50,
    side=Side.ASK,
    limit_price=111,
)

book.replace_order(1, ask_order, new_ask_order) # first arg is agent_id
print("L3 bid data:", book.get_l3_bid_data())
print("L3 ask data:", book.get_l3_ask_data())
print("old_order.order_id:", agent.messages[-1][1].old_order.order_id)
print("new_order.order_id:", agent.messages[-1][1].new_order.order_id)
# Out:
# L3 bid data: [(100, [20, 30])]
# L3 ask data: [(111, [50])]
# old_order.order_id: 7
# new_order.order_id: 12

# %%
# book.pretty_print(silent=False)

# %% [markdown]
# ### Working with real data

# %%
# define load paths
raw_itch_load_path = parent_folder_path + '/dataset/raw/ITCH/'
processed_dataset = '03272019.NASDAQ_ITCH50_AAPL_message_proc.npy'
proc_data_dir = os.path.join('dataset/proc/ITCH/full_view/', processed_dataset)
proc_data_dir = parent_folder_path + '/' + proc_data_dir
symbols_load_path = parent_folder_path + '/dataset/symbols/'
symbols_file = sorted(glob(symbols_load_path + '*sp500*.txt'))[0]

# locate raw ITCH data
itch_message_files = sorted(glob(raw_itch_load_path + '*message*.csv'))
itch_book_files = sorted(glob(raw_itch_load_path + '*book*.csv'))
print('found', len(itch_message_files), 'ITCH message files')
print('found', len(itch_book_files), 'ITCH book files')

# create reverse ticker symbol mapping (key is index, value is ticker)
# print(symbols_file)
tickers = {}
with open(symbols_file) as f:
    idx = 0
    for line in f:
        idx += 1
        # tickers[line.strip()] = idx
        tickers[idx] = line.strip()
# print("Number of unique symbols:", len(tickers))

# load raw ITCH data (book)
symbols = []
for m_f, b_f in tqdm(zip(itch_message_files, itch_book_files)):
    if '03272019' not in m_f:
        continue
    # print(m_f)
    print(b_f)
    
    itch_messages = itch_preproc.load_message_df(m_f)

    itch_book = pd.read_csv(
        b_f,
        # index_col=False,
        # header=None
    )
    assert len(itch_messages) == len(itch_book)

    # remove disallowed order types
    allowed_events=['A','E','C','D','R']
    itch_messages = itch_messages.loc[itch_messages.type.isin(allowed_events)]
    # make sure book is same length as messages
    itch_book = itch_book.loc[itch_messages.index]

    # print("ITCH messages shape:", itch_messages.shape)
    print("ITCH book shape:", itch_book.shape)

    # # remove time field from ITCH book data
    # itch_book = itch_book.drop(columns=['time'])

    # symbol to store in list and use to create OB objects in loop later
    symbol = m_f.rsplit('/', maxsplit=1)[-1][:-12].rsplit('_', maxsplit=1)[-1]
    print("Adding symbol:", symbol)
    symbols.append(symbol)

# load processed ITCH data (messages)
proc_messages = np.array(np.load(proc_data_dir, mmap_mode='r'))
assert len(itch_book) == len(proc_messages) + 1 # off by 1 bc of first message
print("proc_messages.shape:", proc_messages.shape)
print("proc_messages:", proc_messages)
print([ "ticker", "order_id",
        "event_type", "direction", "price_abs", "price", "fill_size", "remain_size",
        "delta_t_s", "delta_t_ns", "time_s", "time_ns", "old_id",
        "price_ref", "fill_size_ref", "time_s_ref", "time_ns_ref", "old_price_abs"])
# Out:
# found 8 ITCH message files
# found 8 ITCH book files
# 0it [00:00, ?it/s]
# /home/aaron/Documents/Github/MarketSimT/dataset/raw/ITCH/03272019.NASDAQ_ITCH50_AAPL_book_20.csv
# 8it [00:04,  1.69it/s]
# ITCH book shape: (2003141, 81)
# Adding symbol: AAPL
# proc_messages.shape: (2003140, 18)
# proc_messages: [[       40     15969         1 ...     -9999     -9999     -9999]
#  [       40     20677         1 ...     -9999     -9999     -9999]
#  [       40     22061         1 ...     -9999     -9999     -9999]
#  ...
#  [       40 335312241         4 ...     56890 566837429     -9999]
#  [       40 343725045         4 ...     57309 388685794     -9999]
#  [       40 353209329         4 ...     57799 533545153     -9999]]
# ['ticker', 'order_id', 'event_type', 'direction', 'price_abs', 'price', 'fill_size', 'remain_size', 'delta_t_s', 'delta_t_ns', 'time_s', 'time_ns', 'old_id', 'price_ref', 'fill_size_ref', 'time_s_ref', 'time_ns_ref', 'old_price_abs']

# %%
itch_book
# Out:
#                    time  1_bid_price  1_bid_vol  1_ask_price  1_ask_vol  \
# 0        14400006432545          NaN        NaN       207.85       18.0
# 1        14400008777412       129.33      100.0       207.85       18.0
# 2        14400016498868       129.33      100.0       207.85       18.0
# 3        14400017857990       129.33      100.0       207.85       18.0
# 4        14403597489791       129.33      100.0       192.70      300.0
# ...                 ...          ...        ...          ...        ...
# 2010131  72000073334596       188.00        1.0       188.99     1000.0
# 2010132  72000073447563       175.00       50.0       188.99     1000.0
# 2010133  72000073477970          NaN        NaN       188.99     1000.0
# 2010134  72000074023439          NaN        NaN       188.99     1000.0
# 2010135  72000074213874          NaN        NaN          NaN        NaN
#
#          2_bid_price  2_bid_vol  2_ask_price  2_ask_vol  3_bid_price  ...  \
# 0                NaN        NaN          NaN        NaN          NaN  ...
# 1                NaN        NaN          NaN        NaN          NaN  ...
# 2             114.94        1.0          NaN        NaN          NaN  ...
# 3             114.94        1.0          NaN        NaN        98.39  ...
# 4             114.94        1.0       207.85       18.0        98.39  ...
# ...              ...        ...          ...        ...          ...  ...
# 2010131       175.00       50.0       195.00     2600.0          NaN  ...
# 2010132          NaN        NaN       195.00     2600.0          NaN  ...
# 2010133          NaN        NaN       195.00     2600.0          NaN  ...
# 2010134          NaN        NaN          NaN        NaN          NaN  ...
# 2010135          NaN        NaN          NaN        NaN          NaN  ...
#
#          18_ask_price  18_ask_vol  19_bid_price  19_bid_vol  19_ask_price  \
# 0                 NaN         NaN           NaN         NaN           NaN
# 1                 NaN         NaN           NaN         NaN           NaN
# 2                 NaN         NaN           NaN         NaN           NaN
# 3                 NaN         NaN           NaN         NaN           NaN
# 4                 NaN         NaN           NaN         NaN           NaN
# ...               ...         ...           ...         ...           ...
# 2010131           NaN         NaN           NaN         NaN           NaN
# 2010132           NaN         NaN           NaN         NaN           NaN
# 2010133           NaN         NaN           NaN         NaN           NaN
# 2010134           NaN         NaN           NaN         NaN           NaN
# 2010135           NaN         NaN           NaN         NaN           NaN
#
#          19_ask_vol  20_bid_price  20_bid_vol  20_ask_price  20_ask_vol
# 0               NaN           NaN         NaN           NaN         NaN
# 1               NaN           NaN         NaN           NaN         NaN
# 2               NaN           NaN         NaN           NaN         NaN
# 3               NaN           NaN         NaN           NaN         NaN
# 4               NaN           NaN         NaN           NaN         NaN
# ...             ...           ...         ...           ...         ...
# 2010131         NaN           NaN         NaN           NaN         NaN
# 2010132         NaN           NaN         NaN           NaN         NaN
# 2010133         NaN           NaN         NaN           NaN         NaN
# 2010134         NaN           NaN         NaN           NaN         NaN
# 2010135         NaN           NaN         NaN           NaN         NaN
#
# [2003141 rows x 81 columns]

# %%
proc_messages[0:10]
# Out:
# array([[       40,     15969,         1,         0,     12933,       999,
#               100,     -9999,         0,   2344867,     14400,   8777412,
#             -9999,     -9999,     -9999,     -9999,     -9999,     -9999],
#        [       40,     20677,         1,         0,     11494,      -999,
#                 1,     -9999,         0,   7721456,     14400,  16498868,
#             -9999,     -9999,     -9999,     -9999,     -9999,     -9999],
#        [       40,     22061,         1,         0,      9839,      -999,
#                 1,     -9999,         0,   1359122,     14400,  17857990,
#             -9999,     -9999,     -9999,     -9999,     -9999,     -9999],
#        [       40,     98453,         1,         1,     19270,       999,
#               300,     -9999,         3, 579631801,     14403, 597489791,
#             -9999,     -9999,     -9999,     -9999,     -9999,     -9999],
#        [       40,     99329,         1,         1,     21490,       999,
#                85,     -9999,         0, 109631363,     14403, 707121154,
#             -9999,     -9999,     -9999,     -9999,     -9999,     -9999],
#        [       40,     99333,         1,         1,     22500,       999,
#               150,     -9999,         0,     40373,     14403, 707161527,
#             -9999,     -9999,     -9999,     -9999,     -9999,     -9999],
#        [       40,     99997,         1,         1,     22500,       999,
#                 5,     -9999,         0, 100599579,     14403, 807761106,
#             -9999,     -9999,     -9999,     -9999,     -9999,     -9999],
#        [       40,    106201,         1,         0,     18573,       999,
#                25,     -9999,         1, 402338889,     14405, 210099995,
#             -9999,     -9999,     -9999,     -9999,     -9999,     -9999],
#        [       40,    121169,         1,         0,     16700,      -999,
#                15,     -9999,         4, 871946246,     14410,  82046241,
#             -9999,     -9999,     -9999,     -9999,     -9999,     -9999],
#        [       40,    121173,         1,         0,     15500,      -999,
#                12,     -9999,         0,    131437,     14410,  82177678,
#             -9999,     -9999,     -9999,     -9999,     -9999,     -9999]])

# %%
print("Number of unique symbols:", len(tickers))
print(tickers[proc_messages[0][0]])
symbols
# Out:
# Number of unique symbols: 503
# AAPL
# ['AAPL']

# %%
def merge_lists(list1, list2):
    '''Merge two lists into one by alternating elements from each list.'''
    list = []
    for item1, item2 in zip(list1, list2):
        list.append(item1)
        list.append(item2)
    return list

def validate_book(sim_book, actual_book, book_idx, n_levels=20):
    # pad and format simulated data
    sim_bids = sim_book.get_l2_bid_data()
    sim_bids += [(0,0)] * (n_levels - len(sim_bids))
    sim_asks = sim_book.get_l2_ask_data()
    sim_asks += [(0,0)] * (n_levels - len(sim_asks))
    sim_book = merge_lists(sim_bids, sim_asks)[:n_levels*2]

    # format actual data
    b_prices = actual_book.iloc[book_idx, 1::2].mul(100).fillna(0).astype(int).values # bid and ask prices
    b_vol = actual_book.iloc[book_idx, 2::2].fillna(0).astype(int).values # bid and ask volumes
    actual_book = list(zip(b_prices, b_vol))

    # compare
    # print(sim_book)
    # print(actual_book)
    assert sim_book == actual_book, f"Book {book_idx} not validated. Simulated book: {sim_book}, Actual book: {actual_book}"
    # print(f"Book {book_idx} validated.")

# %%
# init new book under nasdaq agent
nasdaq_agent = FakeExchangeAgent()

# create a dictionary of order books based on each symbol in symbols
order_books = {}
for symbol in symbols:
    order_books[symbol] = OrderBook(nasdaq_agent, symbol)

# empty book
assert order_books[tickers[proc_messages[0][0]]].bids == order_books[tickers[proc_messages[0][0]]].asks == []

# %%
# first message is missing in proc_messages, so we'll use the raw message file to start the book
first_message = itch_messages.iloc[0]
print(first_message)

# insert bid order
bid_order = LimitOrder(
    order_id=first_message['id'],
    agent_id=1, # world agent, leave alone for now
    time_placed=first_message['time'],
    symbol=symbols[0],
    quantity=int(first_message['size']),
    side=Side.BID if first_message['side'] == 0 else Side.ASK,
    limit_price=int(first_message['price']*100),
)
order_books[symbols[0]].handle_limit_order(bid_order)

print("L3 bid data:", order_books[symbols[0]].get_l3_bid_data())
print("L3 ask data:", order_books[symbols[0]].get_l3_ask_data())
nasdaq_agent.messages
# Out:
# time        14400006432545
# type                     A
# id                   13301
# side                     1
# size                  18.0
# price               207.85
# cancSize               NaN
# execSize               NaN
# oldId                  NaN
# oldSize                NaN
# oldPrice               NaN
# mpid                   NaN
# Name: 0, dtype: object
# L3 bid data: []
# L3 ask data: [(20785, [18])]
# [(1,
#   OrderAcceptedMsg(message_id=369366, order=(Agent 1 @ 1970-01-01 04:00:00) : ASK 18 AAPL @ $207.85))]

# %%
# [ "ticker", "order_id",
# "event_type", "direction", "price_abs", "price", "fill_size", "remain_size",
# "delta_t_s", "delta_t_ns", "time_s", "time_ns", "old_id",
# "price_ref", "fill_size_ref", "time_s_ref", "time_ns_ref", "old_price_abs"]

# init variables to keep track of previous time, price, etc.
prev_time = first_message['time']
prev_price = int(first_message['price']*100)
book_idx = 1 # start at 1 because we already handled the first message
# order_dict = {} # store order objects for each order_id; use for ref order types (3, 4, 5)

# iterate through messages and update order books
for msg in proc_messages:
    # print(msg)
    symbol = tickers[msg[0]]
    # print("Symbol:", symbol)
    order_id = msg[1]
    # print("Order ID:", order_id)
    event_type = msg[2]
    # print("Event Type:", event_type)
    # direction = Side.BID if msg[3] == 0 else Side.ASK
    # print("Direction:", direction)
    if abs(msg[5]) < 999: # if price was not truncated or NaN
        # price = msg[5] + prev_price
        # calculate reference price (previous mid price)
        mid_price = (((itch_book.iloc[book_idx-1, 1] * 100) + (itch_book.iloc[book_idx-1, 3] * 100)) / 2) // 1
        price = int(mid_price) + msg[5]
        # TODO: Change mid_price to be calculated from order book object
    else: # use price_abs
        price = msg[4]
    # print("Price:", price)
    # verify time correctness
    assert prev_time + (msg[8]*1000000000) + msg[9] == (msg[10] * 1000000000) + msg[11]
    time = prev_time + (msg[8]*1000000000) + msg[9]
    # print("Time:", time)

    # handle order based on event type
    if event_type == 1:
        # ADD LIMIT ORDER
        direction = Side.BID if msg[3] == 0 else Side.ASK
        # print("Direction:", direction)
        fill_size = msg[6]
        # print("Fill Size:", fill_size)
        order = LimitOrder(
            order_id=order_id,
            agent_id=1, # world agent, leave alone for now
            time_placed=time,
            symbol=symbol,
            quantity=fill_size,
            side=direction,
            limit_price=price,
        )
        order_books[symbol].handle_limit_order(order)
    elif event_type == 2:
        # EXECUTE ORDER
        fill_size = msg[6]
        # print("Fill Size:", fill_size)
        direction = Side.BID if msg[3] == 1 else Side.ASK # opposite of direction in non-execution messages
        # print("Direction:", direction)
        order = MarketOrder(
            order_id=order_id,
            agent_id=1, # world agent, leave alone for now
            time_placed=time,
            symbol=symbol,
            quantity=fill_size,
            side=direction, # Buy Order if Side.BID (remove liquidity from ask side), Sell Order if Side.ASK (remove liquidity from bid side)
        )
        order_books[symbol].handle_market_order(order)
    elif event_type == 3:
        # EXECUTE ORDER WITH PRICE DIFFERENT THAN DISPLAY
        # This order type is most likely an execution of a price-to-comply order, which is handled by the simulator
        # but this not encoded in the ITCH data beforehand, so we cannot know whether an order is price-to-comply at the time of submission
        # therefore, we handle this event type as a modifed order and then regular execution order (for now, until we revise the data processing)

        # modfify the matched limit order
        direction = Side.BID if msg[3] == 0 else Side.ASK
        ref_order_time = (msg[15] * 1000000000) + msg[16]
        ref_order_size = msg[14]
        ref_order_price = msg[17] # old_price_abs (not mid_price so we cannot calculate using price_ref msg[13])
        # define original order
        original_order = LimitOrder(
            order_id=order_id,
            agent_id=1, # world agent, leave alone for now
            time_placed=ref_order_time,
            symbol=symbol,
            quantity=ref_order_size,
            side=direction,
            limit_price=ref_order_price,
        )
        # define modified order
        # modified_price = msg[4]
        modified_order = LimitOrder(
            order_id=order_id,
            agent_id=1, # world agent, leave alone for now
            time_placed=ref_order_time,
            symbol=symbol,
            quantity=ref_order_size,
            side=direction,
            limit_price=price,
        )
        order_books[symbol].modify_order(original_order, modified_order)
        # execute the modified order
        fill_size = msg[6]
        # print("Fill Size:", fill_size)
        direction = Side.BID if msg[3] == 1 else Side.ASK # opposite of direction in non-execution messages
        # print("Direction:", direction)
        order = MarketOrder(
            order_id=order_id,
            agent_id=1, # world agent, leave alone for now
            time_placed=time,
            symbol=symbol,
            quantity=fill_size,
            side=direction, # Buy Order if Side.BID (remove liquidity from ask side), Sell Order if Side.ASK (remove liquidity from bid side)
        )
        order_books[symbol].handle_market_order(order)
    elif event_type == 4:
        # CANCEL ORDER
        direction = Side.BID if msg[3] == 0 else Side.ASK
        # print("Direction:", direction)
        ref_order_time = (msg[15] * 1000000000) + msg[16]
        if msg[7] == 0:
            # FULL DELETION
            fill_size = msg[6]
            # print("Cancel Size:", fill_size)
            order = LimitOrder(
                order_id=order_id,
                agent_id=1, # world agent, leave alone for now
                time_placed=ref_order_time,
                symbol=symbol,
                quantity=fill_size,
                # quantity=msg[14], # total size of order when placed
                side=direction,
                limit_price=price,
            )
            order_books[symbol].cancel_order(order)
        else:
            # PARTIAL CANCELLATION
            cancel_size = msg[6]
            # print("Partial Cancel Size:", cancel_size)
            # ref_order_size = msg[14]
            ref_order_size = msg[7] + cancel_size # total size of order before partial cancel
            order = LimitOrder(
                order_id=order_id,
                agent_id=1, # world agent, leave alone for now
                time_placed=ref_order_time,
                symbol=symbol,
                quantity=ref_order_size,
                side=direction,
                limit_price=price,
            )
            order_books[symbol].partial_cancel_order(order, cancel_size)
    elif event_type == 5:
        # REPLACE ORDER
        direction = Side.BID if msg[3] == 0 else Side.ASK
        # print("Direction:", direction)
        old_order_id = msg[12]
        old_order_time = (msg[15] * 1000000000) + msg[16]
        old_order_size = msg[14]
        old_order_price = msg[17] # old_price_abs (not mid_price so we cannot calculate using price_ref msg[13])
        # define old order
        old_order = LimitOrder(
            order_id=old_order_id,
            agent_id=1, # world agent, leave alone for now
            time_placed=old_order_time,
            symbol=symbol,
            quantity=old_order_size,
            side=direction,
            limit_price=old_order_price,
        )
        new_order_size = msg[6]
        # define new order
        new_order = LimitOrder(
            order_id=order_id,
            agent_id=1, # world agent, leave alone for now
            time_placed=time,
            symbol=symbol,
            quantity=new_order_size,
            side=direction,
            limit_price=price,
        )
        order_books[symbol].replace_order(1, old_order, new_order) # first arg is agent_id (world agent)
    else:
        raise NotImplementedError("Event type not implemented")

    if order_id == 7819469:
        print("msg:", msg)
        print("Event Type:", event_type)
        sim_bids = order_books[symbol].get_l2_bid_data()
        sim_bids += [(0,0)] * (20 - len(sim_bids))
        sim_asks = order_books[symbol].get_l2_ask_data()
        sim_asks += [(0,0)] * (20 - len(sim_asks))
        sim_book = merge_lists(sim_bids, sim_asks)[:20*2]
        print(f"Simulated book at time {time}: {sim_book}")
        print("Order object quantity:", order.quantity)
        print("Messages order: ", nasdaq_agent.messages[-1][1].order)
        print("Messages order quantity: ", nasdaq_agent.messages[-1][1].order.quantity)
        print("")

    # compare simulated order book with actual order book
    assert int(itch_book.iloc[book_idx].time) == time, f"Time mismatch: {int(itch_book.iloc[book_idx].time)} != {time}"
    validate_book(order_books[symbol], itch_book, book_idx)
    book_idx += 1

    # update previous time and price
    prev_time = time
    prev_price = price

    # # store order object (use for reference order types: 3, 4, 5)
    # order_dict[order_id] = order
# Out:
# order.quantity:  400
# book[0].visible_orders:  [((Agent 1 @ 1970-01-01 09:30:00) : BID 20 AAPL @ $188.70, {}), ((Agent 1 @ 1970-01-01 09:30:00) : BID 27 AAPL @ $188.70, {}), ((Agent 1 @ 1970-01-01 09:30:00) : BID 1 AAPL @ $188.70, {}), ((Agent 1 @ 1970-01-01 09:30:00) : BID 25 AAPL @ $188.70, {}), ((Agent 1 @ 1970-01-01 09:30:00) : BID 4 AAPL @ $188.70, {}), ((Agent 1 @ 1970-01-01 09:30:00) : BID 7 AAPL @ $188.70, {}), ((Agent 1 @ 1970-01-01 09:30:00) : BID 13 AAPL @ $188.70, {}), ((Agent 1 @ 1970-01-01 09:30:00) : BID 100 AAPL @ $188.70, {}), ((Agent 1 @ 1970-01-01 09:30:00) : BID 119 AAPL @ $188.70, {}), ((Agent 1 @ 1970-01-01 09:30:00) : BID 6 AAPL @ $188.70, {}), ((Agent 1 @ 1970-01-01 09:30:00) : BID 150 AAPL @ $188.70, {})]
# visible 0:  7075501
# visible 1:  7089453
# 2
# msg: [       40   7819469         1         1     18888        17       400
#      -9999         0         0     34200 606488029     -9999     -9999
#      -9999     -9999     -9999     -9999]
# Event Type: 1
# Simulated book at time 34200606488029: [(18870, 472), (18872, 1000), (18858, 2), (18875, 4296), (18849, 31), (18877, 19), (18837, 100), (18880, 310), (18823, 100), (18884, 419), (18821, 400), (18885, 17), (18812, 200), (18888, 450), (18811, 50), (18889, 100), (18810, 500), (18890, 10), (18805, 200), (18894, 300), (18802, 400), (18895, 700), (18800, 460), (18914, 500), (18793, 200), (18916, 300), (18787, 100), (18918, 200), (18785, 100), (18937, 200), (18782, 200), (18938, 300), (18780, 1000), (18945, 100), (18777, 100), (18948, 100), (18760, 100), (18949, 100), (18757, 50), (18956, 100)]
# Order object quantity: 400
# Messages order:  (Agent 1 @ 1970-01-01 09:30:00) : ASK 400 AAPL @ $188.88
# Messages order quantity:  400
#
# order.quantity:  365
# book[0].visible_orders:  [((Agent 1 @ 1970-01-01 09:28:19) : ASK 50 AAPL @ $188.88, {}), ((Agent 1 @ 1970-01-01 09:30:00) : ASK 400 AAPL @ $188.88, {}), ((Agent 1 @ 1970-01-01 09:30:01) : ASK 100 AAPL @ $188.88, {})]
# visible 0:  9028925
# visible 1:  7819469
# 4
# 5
# order.quantity:  315
# book[0].visible_orders:  [((Agent 1 @ 1970-01-01 09:30:00) : ASK 400 AAPL @ $188.88, {}), ((Agent 1 @ 1970-01-01 09:30:01) : ASK 100 AAPL @ $188.88, {})]
# visible 0:  7819469
# visible 1:  9982133
# 4
# 6
# order.quantity:  315
# matched_order:  (Agent 1 @ 1970-01-01 09:30:00) : ASK 315 AAPL @ $188.88
# matched_order order_id:  7819469
# matched_order quantity:  315
# matched_order time_placed:  34200606488029
# book[0].visible_orders:  [((Agent 1 @ 1970-01-01 09:30:00) : ASK 400 AAPL @ $188.88, {}), ((Agent 1 @ 1970-01-01 09:30:01) : ASK 100 AAPL @ $188.88, {})]
# msg: [       40   7819469         2         1     18888         4       365
#         35         0         0     34223 232709799     -9999        17
#        400     34200 606488029     -9999]
# Event Type: 2
# Simulated book at time 34223232709799: [(18881, 200), (18888, 185), (18878, 100), (18889, 100), (18877, 100), (18890, 1573), (18876, 100), (18893, 1000), (18875, 400), (18895, 700), (18873, 100), (18899, 250), (18871, 100), (18900, 6726), (18870, 100), (18903, 25), (18869, 100), (18906, 100), (18866, 100), (18907, 500), (18860, 200), (18910, 2060), (18845, 500), (18914, 500), (18842, 740), (18916, 400), (18841, 700), (18918, 300), (18833, 50), (18920, 130), (18831, 300), (18923, 30), (18829, 60), (18925, 200), (18827, 1), (18929, 30), (18825, 536), (18930, 10), (18824, 440), (18934, 100)]
# Order object quantity: 365
# Messages order:  (Agent 1 @ 1970-01-01 09:30:23) : MKT Order BID 315 AAPL
# Messages order quantity:  315
#
# visible:  [((Agent 1 @ 1970-01-01 09:30:00) : ASK 85 AAPL @ $188.88, {}), ((Agent 1 @ 1970-01-01 09:30:01) : ASK 100 AAPL @ $188.88, {}), ((Agent 1 @ 1970-01-01 09:30:23) : ASK 100 AAPL @ $188.88, {})]
# visible 0:  7819469
# visible 1:  9982133
# visible 2:  10766189
# ((Agent 1 @ 1970-01-01 09:30:00) : ASK 85 AAPL @ $188.88, {})
# (Agent 1 @ 1970-01-01 09:30:00) : ASK 85 AAPL @ $188.88
# cancel order order_id:  7819469
# cancel order agent_id:  1
# cancel order quantity:  85
# cancel order side:  Side.ASK
# cancel order time_placed:  34200606488029
# visible:  [((Agent 1 @ 1970-01-01 09:30:01) : ASK 100 AAPL @ $188.88, {}), ((Agent 1 @ 1970-01-01 09:30:23) : ASK 100 AAPL @ $188.88, {})]
# visible 0:  9982133
# visible 1:  10766189
# hidden:  []
# {}
# msg: [       40   7819469         4         1     18888         3        35
#          0         0   2939403     34223 237674883     -9999        17
#        400     34200 606488029     -9999]
# Event Type: 4
# Simulated book at time 34223237674883: [(18883, 100), (18888, 200), (18878, 100), (18889, 100), (18877, 100), (18890, 1673), (18876, 100), (18893, 1000), (18875, 400), (18895, 700), (18873, 100), (18899, 250), (18871, 100), (18900, 6726), (18870, 100), (18903, 25), (18869, 100), (18906, 100), (18866, 100), (18907, 500), (18860, 200), (18910, 2060), (18845, 500), (18914, 500), (18842, 740), (18916, 400), (18841, 700), (18918, 300), (18833, 50), (18920, 130), (18831, 300), (18923, 30), (18829, 60), (18925, 200), (18827, 1), (18929, 30), (18825, 536), (18930, 10), (18824, 440), (18934, 100)]
# Order object quantity: 35
# Messages order:  (Agent 1 @ 1970-01-01 09:30:00) : ASK 85 AAPL @ $188.88
# Messages order quantity:  85
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[265], line 219
#     217 # compare simulated order book with actual order book
#     218 assert int(itch_book.iloc[book_idx].time) == time, f"Time mismatch: {int(itch_book.iloc[book_idx].time)} != {time}"
# --> 219 validate_book(order_books[symbol], itch_book, book_idx)
#     220 book_idx += 1
#     222 # update previous time and price
#
# Cell In[149], line 25, in validate_book(sim_book, actual_book, book_idx, n_levels)
#      20 actual_book = list(zip(b_prices, b_vol))
#      22 # compare
#      23 # print(sim_book)
#      24 # print(actual_book)
# ---> 25 assert sim_book == actual_book, f"Book {book_idx} not validated. Simulated book: {sim_book}, Actual book: {actual_book}"
#
# AssertionError: Book 15545 not validated. Simulated book: [(18883, 100), (18888, 200), (18878, 100), (18889, 100), (18877, 100), (18890, 1673), (18876, 100), (18893, 1000), (18875, 400), (18895, 700), (18873, 100), (18899, 250), (18871, 100), (18900, 6726), (18870, 100), (18903, 25), (18869, 100), (18906, 100), (18866, 100), (18907, 500), (18860, 200), (18910, 2060), (18845, 500), (18914, 500), (18842, 740), (18916, 400), (18841, 700), (18918, 300), (18833, 50), (18920, 130), (18831, 300), (18923, 30), (18829, 60), (18925, 200), (18827, 1), (18929, 30), (18825, 536), (18930, 10), (18824, 440), (18934, 100)], Actual book: [(18883, 100), (18888, 250), (18878, 100), (18889, 100), (18877, 100), (18890, 1673), (18876, 100), (18893, 1000), (18875, 400), (18895, 700), (18873, 100), (18899, 250), (18871, 100), (18900, 6726), (18870, 100), (18903, 25), (18869, 100), (18906, 100), (18866, 100), (18907, 500), (18860, 200), (18910, 2060), (18845, 500), (18914, 500), (18842, 740), (18916, 400), (18841, 700), (18918, 300), (18833, 50), (18920, 130), (18831, 300), (18923, 30), (18829, 60), (18925, 200), (18827, 1), (18929, 30), (18825, 536), (18930, 10), (18824, 440), (18934, 100)]

# %% [markdown]
# **Validation note**
# The order book has a mismatch at timestep 34223237674883 (book_idx=15545 not validated) due to an order being executed out of order and subsequently making the volume of a cancel order mismatched with the actual book data.
# ```
# Simulated Book: [(18883, 100), (18888, 200), (18878, 100), (18889, 100), (18877, 100), (18890, 1673), (18876, 100), (18893, 1000), (18875, 400), (18895, 700), (18873, 100), (18899, 250), (18871, 100), (18900, 6726), (18870, 100), (18903, 25), (18869, 100), (18906, 100), (18866, 100), (18907, 500), (18860, 200), (18910, 2060), (18845, 500), (18914, 500), (18842, 740), (18916, 400), (18841, 700), (18918, 300), (18833, 50), (18920, 130), (18831, 300), (18923, 30), (18829, 60), (18925, 200), (18827, 1), (18929, 30), (18825, 536), (18930, 10), (18824, 440), (18934, 100)]
#
# Actual Book: [(18883, 100), (18888, 250), (18878, 100), (18889, 100), (18877, 100), (18890, 1673), (18876, 100), (18893, 1000), (18875, 400), (18895, 700), (18873, 100), (18899, 250), (18871, 100), (18900, 6726), (18870, 100), (18903, 25), (18869, 100), (18906, 100), (18866, 100), (18907, 500), (18860, 200), (18910, 2060), (18845, 500), (18914, 500), (18842, 740), (18916, 400), (18841, 700), (18918, 300), (18833, 50), (18920, 130), (18831, 300), (18923, 30), (18829, 60), (18925, 200), (18827, 1), (18929, 30), (18825, 536), (18930, 10), (18824, 440), (18934, 100)]
# ```
# In the messages, ADD ORDER @ 188.88 (order_id=9028925) is submitted at timestep 34099118707287 and ADD ORDER @ 188.88 (order_id=7819469) is submitted later on at timestep 34200606488029. Yet, the later order (order_id=7819469) is partially executed at timestep 34223232709799 (and remaining order quantity deleted at 34223237674883), even though this order was submitted later and lower in priority than order 9028925. This order (9028925) is reported as being executed at timestep 34223330769625, shortly after the deletion of order 7819469.
#
# This discrepancy may be due to a late reporting error (or perhaps intentionally?) in the message sequence on behalf of NASDAQ, this issue has been identified previously and may be common in NASDAQ ITCH data: https://www.elitetrader.com/et/threads/reconstruction-an-order-book-from-an-itch-feed-am-i-missing-something.247328/. Sometimes executions may be reported late and assigned a special sale condition code so that users know the execution is out of sequence. In the future, we may consider throwing out these kind of orders in the preprocessing step, because there is no way of knowing where in the sequence they truly occur.
#
# One solution for handling this instance (for data validation purposes) would be to handle all order matching, etc. based on the order_id given in the messages rather than the order book's programmed matching algorithm. This is not ideal for several reasons, one reason being that our current implementation of our AI model does not generate the order_ids itself (this is instead handled externally by the simulator). Therefore, for simulation purposes, we will rely on the programmed matching algorithm (rather than order_id based matching) and consider the simulator/order book implemention "sufficiently validated".
#
# **Debugging log:**
# ```
# order.quantity:  400
# visible 0:  7075501
# visible 1:  7089453
# msg: [       40   7819469         1         1     18888        17       400
#      -9999         0         0     34200 606488029     -9999     -9999
#      -9999     -9999     -9999     -9999]
# Event Type: 1
# Simulated book at time 34200606488029: [(18870, 472), (18872, 1000), (18858, 2), (18875, 4296), (18849, 31), (18877, 19), (18837, 100), (18880, 310), (18823, 100), (18884, 419), (18821, 400), (18885, 17), (18812, 200), (18888, 450), (18811, 50), (18889, 100), (18810, 500), (18890, 10), (18805, 200), (18894, 300), (18802, 400), (18895, 700), (18800, 460), (18914, 500), (18793, 200), (18916, 300), (18787, 100), (18918, 200), (18785, 100), (18937, 200), (18782, 200), (18938, 300), (18780, 1000), (18945, 100), (18777, 100), (18948, 100), (18760, 100), (18949, 100), (18757, 50), (18956, 100)]
# Order object quantity: 400
# Messages order:  (Agent 1 @ 1970-01-01 09:30:00) : ASK 400 AAPL @ $188.88
# Messages order quantity:  400
#
#
# order.quantity:  365
# book[0].visible_orders:  [((Agent 1 @ 1970-01-01 09:28:19) : ASK 50 AAPL @ $188.88, {}), ((Agent 1 @ 1970-01-01 09:30:00) : ASK 400 AAPL @ $188.88, {}), ((Agent 1 @ 1970-01-01 09:30:01) : ASK 100 AAPL @ $188.88, {})]
# visible 0:  9028925
# visible 1:  7819469
# order.quantity:  315
# book[0].visible_orders:  [((Agent 1 @ 1970-01-01 09:30:00) : ASK 400 AAPL @ $188.88, {}), ((Agent 1 @ 1970-01-01 09:30:01) : ASK 100 AAPL @ $188.88, {})]
# visible 0:  7819469
# visible 1:  9982133
# order.quantity:  315
# matched_order:  (Agent 1 @ 1970-01-01 09:30:00) : ASK 315 AAPL @ $188.88
# matched_order order_id:  7819469
# matched_order quantity:  315
# matched_order time_placed:  34200606488029
# book[0].visible_orders:  [((Agent 1 @ 1970-01-01 09:30:00) : ASK 400 AAPL @ $188.88, {}), ((Agent 1 @ 1970-01-01 09:30:01) : ASK 100 AAPL @ $188.88, {})]
# msg: [       40   7819469         2         1     18888         4       365
#         35         0         0     34223 232709799     -9999        17
#        400     34200 606488029     -9999]
# Event Type: 2
# Simulated book at time 34223232709799: [(18881, 200), (18888, 185), (18878, 100), (18889, 100), (18877, 100), (18890, 1573), (18876, 100), (18893, 1000), (18875, 400), (18895, 700), (18873, 100), (18899, 250), (18871, 100), (18900, 6726), (18870, 100), (18903, 25), (18869, 100), (18906, 100), (18866, 100), (18907, 500), (18860, 200), (18910, 2060), (18845, 500), (18914, 500), (18842, 740), (18916, 400), (18841, 700), (18918, 300), (18833, 50), (18920, 130), (18831, 300), (18923, 30), (18829, 60), (18925, 200), (18827, 1), (18929, 30), (18825, 536), (18930, 10), (18824, 440), (18934, 100)]
# Order object quantity: 365
# Messages order:  (Agent 1 @ 1970-01-01 09:30:23) : MKT Order BID 315 AAPL
# Messages order quantity:  315
#
#
# visible:  [((Agent 1 @ 1970-01-01 09:30:00) : ASK 85 AAPL @ $188.88, {}), ((Agent 1 @ 1970-01-01 09:30:01) : ASK 100 AAPL @ $188.88, {}), ((Agent 1 @ 1970-01-01 09:30:23) : ASK 100 AAPL @ $188.88, {})]
# visible 0:  7819469
# visible 1:  9982133
# visible 2:  10766189
# ((Agent 1 @ 1970-01-01 09:30:00) : ASK 85 AAPL @ $188.88, {})
# (Agent 1 @ 1970-01-01 09:30:00) : ASK 85 AAPL @ $188.88
# cancel order order_id:  7819469
# cancel order agent_id:  1
# cancel order quantity:  85
# cancel order side:  Side.ASK
# cancel order time_placed:  34200606488029
# visible:  [((Agent 1 @ 1970-01-01 09:30:01) : ASK 100 AAPL @ $188.88, {}), ((Agent 1 @ 1970-01-01 09:30:23) : ASK 100 AAPL @ $188.88, {})]
# visible 0:  9982133
# visible 1:  10766189
# hidden:  []
# {}
# msg: [       40   7819469         4         1     18888         3        35
#          0         0   2939403     34223 237674883     -9999        17
#        400     34200 606488029     -9999]
# Event Type: 4
# Simulated book at time 34223237674883: [(18883, 100), (18888, 200), (18878, 100), (18889, 100), (18877, 100), (18890, 1673), (18876, 100), (18893, 1000), (18875, 400), (18895, 700), (18873, 100), (18899, 250), (18871, 100), (18900, 6726), (18870, 100), (18903, 25), (18869, 100), (18906, 100), (18866, 100), (18907, 500), (18860, 200), (18910, 2060), (18845, 500), (18914, 500), (18842, 740), (18916, 400), (18841, 700), (18918, 300), (18833, 50), (18920, 130), (18831, 300), (18923, 30), (18829, 60), (18925, 200), (18827, 1), (18929, 30), (18825, 536), (18930, 10), (18824, 440), (18934, 100)]
# Order object quantity: 35
# Messages order:  (Agent 1 @ 1970-01-01 09:30:00) : ASK 85 AAPL @ $188.88
# Messages order quantity:  85
# ```

# %%
# b_prices = itch_book.iloc[book_idx, 1::2].mul(100).fillna(0).astype(int).values # bid and ask prices
# b_vol = itch_book.iloc[book_idx, 2::2].fillna(0).astype(int).values # bid and ask volumes
# actual_book = list(zip(b_prices, b_vol))

# # b_prices = itch_book.iloc[book_idx-1, 1::2].mul(100).fillna(0).astype(int).values # bid and ask prices
# # b_vol = itch_book.iloc[book_idx-1, 2::2].fillna(0).astype(int).values # bid and ask volumes
# # actual_book = list(zip(b_prices, b_vol))

# actual_book

# %%
# order_id

# %%
order.order_id
order.quantity
# Out:
# 35

# %%
# order_books[symbol].history
# direction

# %%
itch_book
# Out:
#                    time  1_bid_price  1_bid_vol  1_ask_price  1_ask_vol  \
# 0        14400006432545          NaN        NaN       207.85       18.0
# 1        14400008777412       129.33      100.0       207.85       18.0
# 2        14400016498868       129.33      100.0       207.85       18.0
# 3        14400017857990       129.33      100.0       207.85       18.0
# 4        14403597489791       129.33      100.0       192.70      300.0
# ...                 ...          ...        ...          ...        ...
# 2010131  72000073334596       188.00        1.0       188.99     1000.0
# 2010132  72000073447563       175.00       50.0       188.99     1000.0
# 2010133  72000073477970          NaN        NaN       188.99     1000.0
# 2010134  72000074023439          NaN        NaN       188.99     1000.0
# 2010135  72000074213874          NaN        NaN          NaN        NaN
#
#          2_bid_price  2_bid_vol  2_ask_price  2_ask_vol  3_bid_price  ...  \
# 0                NaN        NaN          NaN        NaN          NaN  ...
# 1                NaN        NaN          NaN        NaN          NaN  ...
# 2             114.94        1.0          NaN        NaN          NaN  ...
# 3             114.94        1.0          NaN        NaN        98.39  ...
# 4             114.94        1.0       207.85       18.0        98.39  ...
# ...              ...        ...          ...        ...          ...  ...
# 2010131       175.00       50.0       195.00     2600.0          NaN  ...
# 2010132          NaN        NaN       195.00     2600.0          NaN  ...
# 2010133          NaN        NaN       195.00     2600.0          NaN  ...
# 2010134          NaN        NaN          NaN        NaN          NaN  ...
# 2010135          NaN        NaN          NaN        NaN          NaN  ...
#
#          18_ask_price  18_ask_vol  19_bid_price  19_bid_vol  19_ask_price  \
# 0                 NaN         NaN           NaN         NaN           NaN
# 1                 NaN         NaN           NaN         NaN           NaN
# 2                 NaN         NaN           NaN         NaN           NaN
# 3                 NaN         NaN           NaN         NaN           NaN
# 4                 NaN         NaN           NaN         NaN           NaN
# ...               ...         ...           ...         ...           ...
# 2010131           NaN         NaN           NaN         NaN           NaN
# 2010132           NaN         NaN           NaN         NaN           NaN
# 2010133           NaN         NaN           NaN         NaN           NaN
# 2010134           NaN         NaN           NaN         NaN           NaN
# 2010135           NaN         NaN           NaN         NaN           NaN
#
#          19_ask_vol  20_bid_price  20_bid_vol  20_ask_price  20_ask_vol
# 0               NaN           NaN         NaN           NaN         NaN
# 1               NaN           NaN         NaN           NaN         NaN
# 2               NaN           NaN         NaN           NaN         NaN
# 3               NaN           NaN         NaN           NaN         NaN
# 4               NaN           NaN         NaN           NaN         NaN
# ...             ...           ...         ...           ...         ...
# 2010131         NaN           NaN         NaN           NaN         NaN
# 2010132         NaN           NaN         NaN           NaN         NaN
# 2010133         NaN           NaN         NaN           NaN         NaN
# 2010134         NaN           NaN         NaN           NaN         NaN
# 2010135         NaN           NaN         NaN           NaN         NaN
#
# [2003141 rows x 81 columns]

# %%
print("L3 bid data:", order_books[symbols[0]].get_l3_bid_data())
print("L3 ask data:", order_books[symbols[0]].get_l3_ask_data())
nasdaq_agent.messages
# Out:
# L3 bid data: [(18883, [100]), (18878, [100]), (18877, [100]), (18876, [100]), (18875, [100, 300]), (18873, [100]), (18871, [100]), (18870, [100]), (18869, [100]), (18866, [100]), (18860, [200]), (18845, [500]), (18842, [740]), (18841, [700]), (18833, [50]), (18831, [200, 100]), (18829, [60]), (18827, [1]), (18825, [10, 5, 4, 2, 5, 10, 500]), (18824, [400, 30, 10]), (18823, [100, 8]), (18821, [400]), (18820, [15, 2, 23, 75, 3, 1, 1]), (18819, [100]), (18818, [1, 5]), (18817, [15, 41, 1, 10]), (18815, [1, 25]), (18813, [2]), (18811, [50, 1]), (18810, [500, 3, 1, 1, 6, 200]), (18808, [100, 3]), (18806, [25]), (18805, [200, 10]), (18804, [100]), (18802, [300, 10, 8]), (18800, [4, 1, 1, 1, 1, 1, 1, 50, 100, 100, 200, 100, 20, 100, 10, 10, 1, 3, 12, 1, 1, 1, 24, 80, 50, 100, 9, 1, 5, 1, 10, 1, 100, 5, 55, 4, 2, 1, 10, 25, 10, 27, 5, 5, 98, 142, 1000, 95, 100, 60, 60, 100, 10, 48, 6, 1000, 40, 16, 10, 4, 5, 1, 1, 1, 8, 100, 10, 3, 1, 65, 60, 6, 50, 1, 57, 1, 200, 100, 30, 6, 10, 9999, 1, 5, 10, 1000, 30, 50, 10, 4, 100, 7, 25, 1, 200, 52, 3, 28, 9, 10, 12, 8, 178, 4, 2, 150, 300, 100, 30, 100, 1, 100, 100, 15, 100, 5, 16, 10, 130, 32, 250, 17, 40, 3600, 100]), (18798, [100]), (18795, [200]), (18794, [12]), (18793, [200]), (18792, [3, 3, 1, 81]), (18790, [36, 20, 7, 2]), (18789, [100]), (18788, [44, 1]), (18786, [40]), (18785, [1, 5, 3, 200, 1, 90, 100, 100]), (18784, [4]), (18783, [10]), (18782, [200, 1]), (18780, [500, 500, 300, 500, 20, 500, 50, 40, 20, 145]), (18779, [1]), (18777, [100, 1]), (18775, [25, 10]), (18772, [20]), (18767, [10]), (18765, [33]), (18764, [140]), (18763, [2, 1]), (18761, [5]), (18760, [100, 900, 10, 500, 300, 100]), (18759, [20]), (18758, [58]), (18757, [50]), (18755, [30]), (18753, [500]), (18751, [100, 50]), (18750, [10, 100, 9, 110, 110, 25, 4, 60, 65, 53, 5, 20, 21, 4, 30, 200, 100, 250, 500, 33, 300]), (18745, [2000]), (18740, [900, 25, 9]), (18737, [13]), (18735, [500]), (18734, [1, 5]), (18731, [100, 200]), (18730, [200, 400, 2, 250]), (18728, [200]), (18725, [10, 25, 100]), (18723, [200]), (18720, [40, 4]), (18719, [3, 20]), (18716, [64]), (18715, [2000, 742]), (18710, [50, 100]), (18706, [500]), (18705, [1000, 7000]), (18700, [10, 12, 3, 8, 1, 14, 20, 250, 3, 30, 11, 100, 4, 100, 100, 18, 100, 10, 160, 30, 60, 10, 100, 3, 100, 7, 600, 53, 500, 50, 25, 200, 48, 30, 100, 25, 20, 30, 250, 50, 100, 20, 60, 1, 5, 2, 6, 30, 3, 50, 20, 300, 80, 265, 5, 2, 5, 100, 5, 550, 62, 3, 40, 300, 5, 100, 1, 100, 50, 25, 70, 250, 1000, 11, 105, 38]), (18697, [25]), (18695, [5]), (18694, [275, 16, 10]), (18693, [100]), (18692, [100]), (18690, [1, 1, 3, 2, 10, 15, 25, 15, 10]), (18688, [50, 14, 7, 9]), (18687, [100]), (18686, [2, 10]), (18685, [200]), (18683, [300]), (18682, [2, 50]), (18681, [3, 200, 25]), (18680, [10, 200, 50, 100, 3, 25, 50, 10, 10, 100, 70, 25, 100, 30]), (18679, [2, 22, 12, 39, 50, 60, 5, 16, 11, 3, 5, 16, 6, 30, 24, 8, 50, 32, 50, 10, 12, 5, 100, 40, 30, 50, 100, 9, 1, 1, 150, 55, 26, 42, 7, 200, 30, 75, 50, 25, 20, 50]), (18678, [11, 1, 10, 3, 37]), (18677, [5, 5, 50]), (18676, [10]), (18670, [18]), (18660, [50]), (18650, [3, 1000, 100, 1]), (18627, [200]), (18625, [300]), (18620, [171]), (18610, [2]), (18605, [50]), (18602, [300]), (18600, [10, 2, 5, 10, 1, 1, 2, 300, 400, 10, 100, 100]), (18597, [50]), (18589, [50]), (18573, [25, 1, 2]), (18561, [100]), (18520, [6]), (18510, [50]), (18502, [300, 10]), (18501, [5]), (18500, [10, 100, 14, 1, 100, 1275, 100, 100, 2, 4, 10, 20]), (18497, [100, 100]), (18479, [1]), (18475, [1]), (18450, [3]), (18431, [310]), (18425, [1]), (18400, [11, 50, 30, 2, 1, 100, 250]), (18392, [600]), (18375, [1]), (18350, [26, 1500]), (18339, [1450]), (18330, [500]), (18325, [1]), (18314, [1, 100]), (18310, [20]), (18308, [20]), (18300, [11, 100, 1, 100, 69, 200]), (18288, [80]), (18230, [240]), (18222, [9]), (18200, [30, 25, 1, 13, 350, 1, 100]), (18141, [110]), (18120, [100]), (18116, [100, 100, 100]), (18100, [25, 1, 980]), (18092, [600]), (18050, [6]), (18010, [200]), ...
# L3 ask data: [(18888, [100, 100]), (18889, [100]), (18890, [10, 1563, 100]), (18893, [500, 500]), (18895, [400, 300]), (18899, [100, 50, 100]), (18900, [15, 10, 28, 50, 120, 30, 10, 200, 10, 40, 67, 2000, 20, 80, 25, 65, 119, 30, 3, 15, 2, 600, 150, 10, 10, 60, 36, 100, 2, 60, 500, 200, 4, 500, 745, 100, 100, 600, 10]), (18903, [25]), (18906, [100]), (18907, [500]), (18910, [2000, 60]), (18914, [500]), (18916, [300, 100]), (18918, [200, 100]), (18920, [100, 30]), (18923, [30]), (18925, [100, 100]), (18929, [30]), (18930, [10]), (18934, [100]), (18935, [3000, 250]), (18937, [200]), (18938, [300]), (18939, [100]), (18940, [20]), (18941, [787]), (18942, [100, 660]), (18948, [100, 800, 300]), (18949, [100]), (18950, [30, 200, 5, 10, 100, 200, 500, 30, 4, 100, 875, 100]), (18951, [30]), (18954, [100]), (18955, [33]), (18956, [100, 15, 60, 40]), (18958, [600, 300, 118]), (18960, [1]), (18964, [1]), (18965, [5, 300, 15, 1000]), (18968, [100]), (18972, [60]), (18974, [300]), (18975, [100, 150]), (18977, [100]), (18978, [300]), (18979, [300, 200]), (18980, [200, 50, 60, 11]), (18985, [20]), (18988, [50, 100, 500, 100]), (18989, [600, 300]), (18990, [500, 62, 600, 10, 100]), (18994, [120]), (18995, [320, 400, 100]), (18998, [35, 300]), (18999, [7]), (19000, [400, 700, 100, 53, 151, 10, 1350, 100, 700, 90, 1, 25, 18, 160, 100, 1, 44, 5, 2, 8, 70, 10, 28, 45, 54, 12, 2, 11, 77, 74, 47, 60, 52, 8, 19, 10, 6, 22, 29, 20, 20, 10, 26, 15, 6, 64, 500, 17, 127, 6, 200, 51, 30, 125, 31, 100, 50, 15, 10, 50, 30, 5, 42, 100, 150, 100, 20, 14, 30, 1500, 152, 825, 100, 100, 1, 500, 15, 6, 12, 100, 20, 50, 5, 17, 26, 100, 15, 9, 19, 218, 52, 286, 23, 139, 250, 300, 9, 54, 250, 20, 3, 106, 38, 13, 50, 10, 5, 14, 9, 500, 130, 29, 8, 20, 100, 10, 5, 10, 41, 30, 30, 1, 400, 25, 50, 100, 55, 10, 17, 33, 39, 156, 100, 50, 50, 30, 35, 100, 22, 4000, 160, 6, 130, 50, 50, 75, 28, 60, 2, 27, 5, 125, 35, 100, 300, 3, 6, 1, 3, 125, 800, 10, 150, 56, 32, 200, 100, 24, 10, 25, 100, 250, 15, 200, 50, 4, 7, 22, 21, 27, 10, 71, 21, 58, 40, 54, 57, 27, 132, 596, 166, 50, 350, 20, 82, 15, 7, 20, 20, 200, 5, 200, 200, 500, 500, 200, 200, 50, 200, 35, 40, 300, 5, 10, 7, 100, 7, 100, 100, 10, 25, 62, 11, 200, 40, 100, 35, 35]), (19002, [20]), (19003, [10]), (19005, [100, 1000]), (19010, [1000, 500]), (19011, [100]), (19017, [100]), (19018, [6]), (19020, [1000]), (19021, [300]), (19025, [3, 8, 25, 100, 50]), (19026, [1000]), (19030, [10]), (19037, [1000]), (19040, [110, 1]), (19042, [700, 500]), (19043, [50]), (19044, [90]), (19045, [250]), (19046, [400, 100]), (19049, [100]), (19050, [18, 300, 100, 100, 100, 440, 275, 75, 515, 50]), (19052, [17, 25]), (19055, [250, 80]), (19060, [20, 1000, 3000, 290]), (19064, [700]), (19065, [150, 1000]), (19067, [100]), (19068, [15]), (19070, [500, 90, 200]), (19075, [25]), (19079, [300]), (19080, [24, 100]), (19084, [300, 1]), (19085, [35]), (19088, [119, 120, 10, 115]), (19089, [25]), (19091, [25]), (19094, [100]), (19095, [3]), (19096, [200]), (19097, [100]), (19098, [300, 400]), (19100, [100, 14, 80, 200, 76, 390, 50, 51, 53, 6, 12, 5, 100, 200, 5, 50, 6, 265, 10, 50, 10, 30, 50, 50, 80, 100, 200, 200, 81, 140, 100, 72, 110, 15, 50, 10, 50, 58, 10, 100, 50, 10, 25, 4, 45, 11, 42, 100, 500, 15, 9999, 25, 800, 740, 22, 80, 100, 100, 50, 250, 432, 100, 20, 200, 21, 200, 50, 70, 100]), (19101, [150]), (19102, [107]), (19109, [20]), (19110, [39, 250]), (19115, [9]), (19120, [120, 40, 60]), (19122, [500]), (19123, [138]), (19124, [30]), (19125, [200, 300, 12]), (19128, [100]), (19129, [100]), (19130, [140, 100]), (19131, [16]), (19132, [110]), (19133, [333]), (19140, [100, 100]), (19141, [395]), (19142, [100, 538]), (19143, [400]), (19145, [500, 160]), (19148, [10]), (19150, [15]), (19162, [200]), (19165, [112]), (19170, [80]), (19175, [100]), (19187, [150]), (19188, [50]), (19198, [25]), (19200, [30, 200, 1280, 45, 20, 8, 332, 449]), (19201, [5]), (19202, [400]), (19210, [10]), (19228, [200]), (19250, [1, 300, 200, 200, 50]), (19255, [50 ...
# [(1,
#   OrderAcceptedMsg(message_id=94986, order=(Agent 1 @ 1970-01-01 04:00:00) : ASK 18 AAPL @ $207.85)),
#  (1,
#   OrderAcceptedMsg(message_id=94987, order=(Agent 1 @ 1970-01-01 04:00:00) : BID 100 AAPL @ $129.33)),
#  (1,
#   OrderAcceptedMsg(message_id=94988, order=(Agent 1 @ 1970-01-01 04:00:00) : BID 1 AAPL @ $114.94)),
#  (1,
#   OrderAcceptedMsg(message_id=94989, order=(Agent 1 @ 1970-01-01 04:00:00) : BID 1 AAPL @ $98.39)),
#  (1,
#   OrderAcceptedMsg(message_id=94990, order=(Agent 1 @ 1970-01-01 04:00:03) : ASK 300 AAPL @ $192.70)),
#  (1,
#   OrderAcceptedMsg(message_id=94991, order=(Agent 1 @ 1970-01-01 04:00:03) : ASK 85 AAPL @ $214.90)),
#  (1,
#   OrderAcceptedMsg(message_id=94992, order=(Agent 1 @ 1970-01-01 04:00:03) : ASK 150 AAPL @ $225.00)),
#  (1,
#   OrderAcceptedMsg(message_id=94993, order=(Agent 1 @ 1970-01-01 04:00:03) : ASK 5 AAPL @ $225.00)),
#  (1,
#   OrderAcceptedMsg(message_id=94994, order=(Agent 1 @ 1970-01-01 04:00:05) : BID 25 AAPL @ $185.73)),
#  (1,
#   OrderAcceptedMsg(message_id=94995, order=(Agent 1 @ 1970-01-01 04:00:10) : BID 15 AAPL @ $167.00)),
#  (1,
#   OrderAcceptedMsg(message_id=94996, order=(Agent 1 @ 1970-01-01 04:00:10) : BID 12 AAPL @ $155.00)),
#  (1,
#   OrderAcceptedMsg(message_id=94997, order=(Agent 1 @ 1970-01-01 04:00:10) : BID 15 AAPL @ $165.00)),
#  (1,
#   OrderAcceptedMsg(message_id=94998, order=(Agent 1 @ 1970-01-01 04:00:10) : BID 25 AAPL @ $175.00)),
#  (1,
#   OrderAcceptedMsg(message_id=94999, order=(Agent 1 @ 1970-01-01 04:00:10) : BID 12 AAPL @ $155.00)),
#  (1,
#   OrderAcceptedMsg(message_id=95000, order=(Agent 1 @ 1970-01-01 04:00:10) : BID 12 AAPL @ $150.00)),
#  (1,
#   OrderAcceptedMsg(message_id=95001, order=(Agent 1 @ 1970-01-01 04:00:10) : BID 15 AAPL @ $160.00)),
#  (1,
#   OrderAcceptedMsg(message_id=95002, order=(Agent 1 @ 1970-01-01 04:00:10) : BID 11 AAPL @ $169.50)),
#  (1,
#   OrderAcceptedMsg(message_id=95003, order=(Agent 1 @ 1970-01-01 04:00:10) : BID 11 AAPL @ $180.00)),
#  (1,
#   OrderAcceptedMsg(message_id=95004, order=(Agent 1 @ 1970-01-01 04:00:16) : BID 1 AAPL @ $180.00)),
#  (1,
#   OrderCancelledMsg(message_id=95005, order=(Agent 1 @ 1970-01-01 04:00:16) : BID 1 AAPL @ $180.00)),
#  (1,
#   OrderAcceptedMsg(message_id=95006, order=(Agent 1 @ 1970-01-01 04:00:18) : BID 1 AAPL @ $180.01)),
#  (1,
#   OrderCancelledMsg(message_id=95007, order=(Agent 1 @ 1970-01-01 04:00:18) : BID 1 AAPL @ $180.01)),
#  (1,
#   OrderAcceptedMsg(message_id=95008, order=(Agent 1 @ 1970-01-01 04:00:19) : BID 1 AAPL @ $180.02)),
#  (1,
#   OrderAcceptedMsg(message_id=95009, order=(Agent 1 @ 1970-01-01 04:00:20) : BID 10 AAPL @ $187.00)),
#  (1,
#   OrderCancelledMsg(message_id=95010, order=(Agent 1 @ 1970-01-01 04:00:19) : BID 1 AAPL @ $180.02)),
#  (1,
#   OrderAcceptedMsg(message_id=95011, order=(Agent 1 @ 1970-01-01 04:00:32) : BID 200 AAPL @ $188.02)),
#  (1,
#   OrderPartialCancelledMsg(message_id=95012, new_order=(Agent 1 @ 1970-01-01 04:00:32) : BID 100 AAPL @ $188.02)),
#  (1,
#   OrderAcceptedMsg(message_id=95013, order=(Agent 1 @ 1970-01-01 04:00:40) : BID 10 AAPL @ $186.00)),
#  (1,
#   OrderCancelledMsg(message_id=95014, order=(Agent 1 @ 1970-01-01 04:00:32) : BID 100 AAPL @ $188.02)),
#  (1,
#   OrderAcceptedMsg(message_id=95015, order=(Agent 1 @ 1970-01-01 04:00:48) : BID 500 AAPL @ $188.25)),
#  (1,
#   OrderAcceptedMsg(message_id=95016, order=(Agent 1 @ 1970-01-01 04:00:48) : BID 60 AAPL @ $188.28)),
#  (1,
#   OrderAcceptedMsg(message_id=95017, order=(Agent 1 @ 1970-01-01 04:00:53) : ASK 100 AAPL @ $188.55)),
#  (1,
#   OrderExecutedMsg(message_id=95018, order=(Agent 1 @ 1970-01-01 04:00:53) : ASK 10 AAPL @ $188.55 (filled @ $188.55))),
#  (1,
#   OrderExecutedMsg(message_id=95019, order=(Agent 1 @ 1970-01-01 04:00:56) : MKT Order BID 10 AAPL)),
#  (1,
#   OrderAcceptedMsg(message_id=95020, order=(Agent 1 @ 1970-01-01 04:00:57) : BID 10 AAPL @ $185.00)),
#  (1,
#   OrderCancelledMsg(message_id=95021, order=(Agent 1 @ 1970-01-01 04:00:48) : BID 60 AAPL @ $188.28)),
#  (1,
#   OrderAcceptedMsg(message_id=95022, order=(Agent 1 @ 1970-01-01 04:01:20) : BID 60 AAPL @ $188.02)),
#  (1,
#   OrderCancelledMsg(message_id=95023, order=(Agent 1 @ 1970-01-01 04:01:20) : BID 60 AAPL @ $188.02)),
#  (1,
#   OrderCancelledMsg(message_id=95024, order=(Agent 1 @ 1970-01-01 04:00:53) : ASK 90 AAPL @ $188.55)),
#  (1,
#   OrderAcceptedMsg(message_id=95025, order=(Agent 1 @ 1970-01-01 04:02:19) : BID 1 AAPL @ $184.75)),
#  (1,
#   OrderAcceptedMsg(message_id=95026, order=(Agent 1 @ 1970-01-01 04:02:23) : BID 100 AAPL @ $188.26)),
#  (1,
#   OrderCancelledMsg(message_id=95027, order=(Agent 1 @ 1970-01-01 04:00:48) : BID 500 AAPL @ $188.25)),
#  (1,
#   OrderAcceptedMsg(message_id=95028, order=(Agent 1 @ 1970-01-01 04:02:34) : BID 500 AAPL @ $188.40)),
#  (1,
#   OrderAcceptedMsg(message_id=95029, order=(Agent 1 @ 1970-01-01 04:02:39) : BID 1 AAPL @ $184.25)),
#  (1,
#   OrderAcceptedMsg(message_id=95030, order=(Agent 1 @ 1970-01-01 04:02:39) : BID 1 AAPL @ $180.00)),
#  (1,
#   OrderAcceptedMsg(message_id=95031, order=(Agent 1 @ 1970-01-01 04:02:41) : BID 70 AAPL @ $186.70)),
#  (1,
#   OrderCancelledMsg(message_id=95032, order=(Agent 1 @ 1970-01-01 04:02:39) : BID 1 AAPL @ $180.00)),
#  (1,
#   OrderAcceptedMsg(message_id=95033, order=(Agent 1 @ 1970-01-01 04:03:03) : BID 11 AAPL @ $184.00)),
#  (1,
#   OrderAcceptedMsg(message_id=95034, order=(Agent 1 @ 1970-01-01 04:03:23) : BID 1 AAPL @ $183.75)),
#  (1,
#   OrderAcceptedMsg(message_id=95035, order=(Agent 1 @ 1970-01-01 04:03:37) : BID 70 AAPL @ $188.50)),
#  (1,
#   OrderCancelledMsg(message_id=95036, order=(Agent 1 @ 1970-01-01 04:02:41) : BID 70 AAPL @ $186.70)),
#  (1,
#   OrderAcceptedMsg(message_id=95037, order=(Agent 1 @ 1970-01-01 04:03:46) : BID 70 AAPL @ $186.80)),
#  (1,
#   OrderAcceptedMsg(message_id=95038, order=(Agent 1 @ 1970-01-01 04:03:49) : BID 1 AAPL @ $183.25)),
#  (1,
#   OrderAcceptedMsg(message_id=95039, order=(Agent 1 @ 1970-01-01 04:04:05) : BID 11 AAPL @ $183.00)),
#  (1,
#   OrderCancelledMsg(message_id=95040, order=(Agent 1 @ 1970-01-01 04:03:37) : BID 70 AAPL @ $188.50)),
#  (1,
#   OrderCancelledMsg(message_id=95041, order=(Agent 1 @ 1970-01-01 04:02:34) : BID 500 AAPL @ $188.40)),
#  (1,
#   OrderAcceptedMsg(message_id=95042, order=(Agent 1 @ 1970-01-01 04:04:43) : BID 100 AAPL @ $188.26)),
#  (1,
#   OrderCancelledMsg(message_id=95043, order=(Agent 1 @ 1970-01-01 04:03:46) : BID 70 AAPL @ $186.80)),
#  (1,
#   OrderAcceptedMsg(message_id=95044, order=(Agent 1 @ 1970-01-01 04:04:47) : BID 74 AAPL @ $186.90)),
#  (1,
#   OrderCancelledMsg(message_id=95045, order=(Agent 1 @ 1970-01-01 04:04:43) : BID 100 AAPL @ $188.26)),
#  (1,
#   OrderAcceptedMsg(message_id=95046, order=(Agent 1 @ 1970-01-01 04:04:54) : BID 100 AAPL @ $188.30)),
#  (1,
#   OrderAcceptedMsg(message_id=95047, order=(Agent 1 @ 1970-01-01 04:05:21) : ASK 10 AAPL @ $188.92)),
#  (1,
#   OrderCancelledMsg(message_id=95048, order=(Agent 1 @ 1970-01-01 04:04:47) : BID 74 AAPL @ $186.90)),
#  (1,
#   OrderAcceptedMsg(message_id=95049, order=(Agent 1 @ 1970-01-01 04:05:39) : BID 74 AAPL @ $187.00)),
#  (1,
#   OrderAcceptedMsg(message_id=95050, order=(Agent 1 @ 1970-01-01 04:06:07) : ASK 10 AAPL @ $192.70)),
#  (1,
#   OrderAcceptedMsg(message_id=95051, order=(Agent 1 @ 1970-01-01 04:06:28) : BID 100 AAPL @ $187.11)),
#  (1,
#   OrderAcceptedMsg(message_id=95052, order=(Agent 1 @ 1970-01-01 04:06:45) : ASK 11 AAPL @ $188.42)),
#  (1,
#   OrderCancelledMsg(message_id=95053, order=(Agent 1 @ 1970-01-01 04:05:39) : BID 74 AAPL @ $187.00)),
#  (1,
#   OrderAcceptedMsg(message_id=95054, order=(Agent 1 @ 1970-01-01 04:06:51) : BID 73 AAPL @ $187.10)),
#  (1,
#   OrderAcceptedMsg(message_id=95055, order=(Agent 1 @ 1970-01-01 04:06:56) : BID 100 AAPL @ $187.91)),
#  (1,
#   OrderAcceptedMsg(message_id=95056, order=(Agent 1 @ 1970-01-01 04:06:57) : ASK 100 AAPL @ $188.95)),
#  (1,
#   OrderCancelledMsg(message_id=95057, order=(Agent 1 @ 1970-01-01 04:06:56) : BID 100 AAPL @ $187.91)),
#  (1,
#   OrderAcceptedMsg(message_id=95058, order=(Agent 1 @ 1970-01-01 04:06:57) : BID 100 AAPL @ $187.93)),
#  (1,
#   OrderCancelledMsg(message_id=95059, order=(Agent 1 @ 1970-01-01 04:06:57) : BID 100 AAPL @ $187.93)),
#  (1,
#   OrderAcceptedMsg(message_id=95060, order=(Agent 1 @ 1970-01-01 04:06:58) : BID 100 AAPL @ $187.96)),
#  (1,
#   OrderCancelledMsg(message_id=95061, order=(Agent 1 @ 1970-01-01 04:06:58) : BID 100 AAPL @ $187.96)),
#  (1,
#   OrderAcceptedMsg(message_id=95062, order=(Agent 1 @ 1970-01-01 04:06:58) : BID 100 AAPL @ $188.04)),
#  (1,
#   OrderCancelledMsg(message_id=95063, order=(Agent 1 @ 1970-01-01 04:06:58) : BID 100 AAPL @ $188.04)),
#  (1,
#   OrderAcceptedMsg(message_id=95064, order=(Agent 1 @ 1970-01-01 04:06:59) : BID 100 AAPL @ $187.94)),
#  (1,
#   OrderCancelledMsg(message_id=95065, order=(Agent 1 @ 1970-01-01 04:06:57) : ASK 100 AAPL @ $188.95)),
#  (1,
#   OrderAcceptedMsg(message_id=95066, order=(Agent 1 @ 1970-01-01 04:06:59) : ASK 100 AAPL @ $188.94)),
#  (1,
#   OrderCancelledMsg(message_id=95067, order=(Agent 1 @ 1970-01-01 04:06:59) : BID 100 AAPL @ $187.94)),
#  (1,
#   OrderAcceptedMsg(message_id=95068, order=(Agent 1 @ 1970-01-01 04:07:00) : BID 100 AAPL @ $187.96)),
#  (1,
#   OrderCancelledMsg(message_id=95069, order=(Agent 1 @ 1970-01-01 04:07:00) : BID 100 AAPL @ $187.96)),
#  (1,
#   OrderAcceptedMsg(message_id=95070, order=(Agent 1 @ 1970-01-01 04:07:00) : BID 100 AAPL @ $187.97)),
#  (1,
#   OrderCancelledMsg(message_id=95071, order=(Agent 1 @ 1970-01-01 04:07:00) : BID 100 AAPL @ $187.97)),
#  (1,
#   OrderAcceptedMsg(message_id=95072, order=(Agent 1 @ 1970-01-01 04:07:01) : BID 100 AAPL @ $187.96)),
#  (1,
#   OrderCancelledMsg(message_id=95073, order=(Agent 1 @ 1970-01-01 04:07:01) : BID 100 AAPL @ $187.96)),
#  (1,
#   OrderAcceptedMsg(message_id=95074, order=(Agent 1 @ 1970-01-01 04:07:01) : BID 100 AAPL @ $187.91)),
#  (1,
#   OrderCancelledMsg(message_id=95075, order=(Agent 1 @ 1970-01-01 04:07:01) : BID 100 AAPL @ $187.91)),
#  (1,
#   OrderAcceptedMsg(message_id=95076, order=(Agent 1 @ 1970-01-01 04:07:02) : BID 100 AAPL @ $187.99)),
#  (1,
#   OrderCancelledMsg(message_id=95077, order=(Agent 1 @ 1970-01-01 04:07:02) : BID 100 AAPL @ $187.99)),
#  (1,
#   OrderAcceptedMsg(message_id=95078, order=(Agent 1 @ 1970-01-01 04:07:02) : BID 100 AAPL @ $187.95)),
#  (1,
#   OrderCancelledMsg(message_id=95079, order=(Agent 1 @ 1970-01-01 04:07:02) : BID 100 AAPL @ $187.95)),
#  (1,
#   OrderAcceptedMsg(message_id=95080, order=(Agent 1 @ 1970-01-01 04:07:03) : BID 100 AAPL @ $188.03)),
#  (1,
#   OrderExecutedMsg(message_id=95081, order=(Agent 1 @ 1970-01-01 04:06:45) : ASK 6 AAPL @ $188.42 (filled @ $188.42))),
#  (1,
#   OrderExecutedMsg(message_id=95082, order=(Agent 1 @ 1970-01-01 04:07:03) : MKT Order BID 6 AAPL)),
#  (1,
#   OrderExecutedMsg(message_id=95083, order=(Agent 1 @ 1970-01-01 04:06:45) : ASK 5 AAPL @ $188.42 (filled @ $188.42))),
#  (1,
#   OrderExecutedMsg(message_id=95084, order=(Agent 1 @ 1970-01-01 04:07:03) : MKT Order BID 5 AAPL)),
#  (1,
#   OrderCancelledMsg(message_id=95085, order=(Agent 1 @ 1970-01-01 04:06:59) : ASK 100 AAPL @ $188.94)),
#  (1,
#   OrderAcceptedMsg(message_id=95086, order=(Agent 1 @ 1970-01-01 04:07:03) : ASK 100 AAPL @ $189.30)),
#  (1,
#   OrderCancelledMsg(message_id=95087, order=(Agent 1 @ 1970-01-01 04:07:03) : BID 100 AAPL @ $188.03)),
#  (1,
#   OrderAcceptedMsg(message_id=95088, order=(Agent 1 @ 1970-01-01 04:07:03) : BID 100 AAPL @ $187.94)),
#  (1,
#   OrderCancelledMsg(message_id=95089, order=(Agent 1 @ 1970-01-01 04:07:03) : ASK 100 AAPL @ $189.30)),
#  (1,
#   OrderAcceptedMsg(message_id=95090, order=(Agent 1 @ 1970-01-01 04:07:04) : ASK 100 AAPL @ $189.29)),
#  (1,
#   OrderAcceptedMsg(message_id=95091, order=(Agent 1 @ 1970-01-01 04:07:04) : BID 100 AAPL @ $187.90)),
#  (1,
#   OrderCancelledMsg(message_id=95092, order=(Agent 1 @ 1970-01-01 04:07:03) : BID 100 AAPL @ $187.94)),
#  (1,
#   OrderCancelledMsg(message_id=95093, order=(Agent 1 @ 1970-01-01 04:07:04) : ASK 100 AAPL @ $189.29)),
#  (1,
#   OrderAcceptedMsg(message_id=95094, order=(Agent 1 @ 1970-01-01 04:07:05) : ASK 100 AAPL @ $189.28)),
#  (1,
#   OrderCancelledMsg(message_id=95095, order=(Agent 1 @ 1970-01-01 04:07:04) : BID 100 AAPL @ $187.90)),
#  (1,
#   OrderAcceptedMsg(message_id=95096, order=(Agent 1 @ 1970-01-01 04:07:05) : BID 100 AAPL @ $187.92)),
#  (1,
#   OrderCancelledMsg(message_id=95097, order=(Agent 1 @ 1970-01-01 04:07:05) : ASK 100 AAPL @ $189.28)),
#  (1,
#   OrderAcceptedMsg(message_id=95098, order=(Agent 1 @ 1970-01-01 04:07:05) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderCancelledMsg(message_id=95099, order=(Agent 1 @ 1970-01-01 04:07:05) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderCancelledMsg(message_id=95100, order=(Agent 1 @ 1970-01-01 04:07:05) : BID 100 AAPL @ $187.92)),
#  (1,
#   OrderAcceptedMsg(message_id=95101, order=(Agent 1 @ 1970-01-01 04:07:05) : BID 100 AAPL @ $187.96)),
#  (1,
#   OrderAcceptedMsg(message_id=95102, order=(Agent 1 @ 1970-01-01 04:07:06) : ASK 100 AAPL @ $189.28)),
#  (1,
#   OrderCancelledMsg(message_id=95103, order=(Agent 1 @ 1970-01-01 04:07:05) : BID 100 AAPL @ $187.96)),
#  (1,
#   OrderAcceptedMsg(message_id=95104, order=(Agent 1 @ 1970-01-01 04:07:06) : BID 100 AAPL @ $187.99)),
#  (1,
#   OrderCancelledMsg(message_id=95105, order=(Agent 1 @ 1970-01-01 04:07:06) : ASK 100 AAPL @ $189.28)),
#  (1,
#   OrderAcceptedMsg(message_id=95106, order=(Agent 1 @ 1970-01-01 04:07:07) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderCancelledMsg(message_id=95107, order=(Agent 1 @ 1970-01-01 04:07:07) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderAcceptedMsg(message_id=95108, order=(Agent 1 @ 1970-01-01 04:07:08) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderCancelledMsg(message_id=95109, order=(Agent 1 @ 1970-01-01 04:07:08) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderCancelledMsg(message_id=95110, order=(Agent 1 @ 1970-01-01 04:04:54) : BID 100 AAPL @ $188.30)),
#  (1,
#   OrderAcceptedMsg(message_id=95111, order=(Agent 1 @ 1970-01-01 04:07:08) : BID 100 AAPL @ $188.33)),
#  (1,
#   OrderAcceptedMsg(message_id=95112, order=(Agent 1 @ 1970-01-01 04:07:08) : ASK 100 AAPL @ $189.27)),
#  (1,
#   OrderCancelledMsg(message_id=95113, order=(Agent 1 @ 1970-01-01 04:07:06) : BID 100 AAPL @ $187.99)),
#  (1,
#   OrderAcceptedMsg(message_id=95114, order=(Agent 1 @ 1970-01-01 04:07:09) : BID 100 AAPL @ $188.00)),
#  (1,
#   OrderCancelledMsg(message_id=95115, order=(Agent 1 @ 1970-01-01 04:07:08) : ASK 100 AAPL @ $189.27)),
#  (1,
#   OrderAcceptedMsg(message_id=95116, order=(Agent 1 @ 1970-01-01 04:07:09) : ASK 100 AAPL @ $189.26)),
#  (1,
#   OrderCancelledMsg(message_id=95117, order=(Agent 1 @ 1970-01-01 04:07:09) : BID 100 AAPL @ $188.00)),
#  (1,
#   OrderAcceptedMsg(message_id=95118, order=(Agent 1 @ 1970-01-01 04:07:09) : BID 100 AAPL @ $188.01)),
#  (1,
#   OrderCancelledMsg(message_id=95119, order=(Agent 1 @ 1970-01-01 04:07:09) : ASK 100 AAPL @ $189.26)),
#  (1,
#   OrderAcceptedMsg(message_id=95120, order=(Agent 1 @ 1970-01-01 04:07:10) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderCancelledMsg(message_id=95121, order=(Agent 1 @ 1970-01-01 04:07:09) : BID 100 AAPL @ $188.01)),
#  (1,
#   OrderAcceptedMsg(message_id=95122, order=(Agent 1 @ 1970-01-01 04:07:10) : BID 100 AAPL @ $187.97)),
#  (1,
#   OrderCancelledMsg(message_id=95123, order=(Agent 1 @ 1970-01-01 04:07:10) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderAcceptedMsg(message_id=95124, order=(Agent 1 @ 1970-01-01 04:07:10) : ASK 100 AAPL @ $189.23)),
#  (1,
#   OrderAcceptedMsg(message_id=95125, order=(Agent 1 @ 1970-01-01 04:07:10) : BID 30 AAPL @ $188.30)),
#  (1,
#   OrderAcceptedMsg(message_id=95126, order=(Agent 1 @ 1970-01-01 04:07:11) : BID 100 AAPL @ $188.01)),
#  (1,
#   OrderCancelledMsg(message_id=95127, order=(Agent 1 @ 1970-01-01 04:07:10) : BID 100 AAPL @ $187.97)),
#  (1,
#   OrderCancelledMsg(message_id=95128, order=(Agent 1 @ 1970-01-01 04:07:10) : ASK 100 AAPL @ $189.23)),
#  (1,
#   OrderAcceptedMsg(message_id=95129, order=(Agent 1 @ 1970-01-01 04:07:11) : ASK 100 AAPL @ $189.29)),
#  (1,
#   OrderCancelledMsg(message_id=95130, order=(Agent 1 @ 1970-01-01 04:07:11) : BID 100 AAPL @ $188.01)),
#  (1,
#   OrderAcceptedMsg(message_id=95131, order=(Agent 1 @ 1970-01-01 04:07:11) : BID 100 AAPL @ $188.03)),
#  (1,
#   OrderCancelledMsg(message_id=95132, order=(Agent 1 @ 1970-01-01 04:07:11) : ASK 100 AAPL @ $189.29)),
#  (1,
#   OrderAcceptedMsg(message_id=95133, order=(Agent 1 @ 1970-01-01 04:07:11) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderCancelledMsg(message_id=95134, order=(Agent 1 @ 1970-01-01 04:07:11) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderAcceptedMsg(message_id=95135, order=(Agent 1 @ 1970-01-01 04:07:13) : ASK 100 AAPL @ $189.23)),
#  (1,
#   OrderCancelledMsg(message_id=95136, order=(Agent 1 @ 1970-01-01 04:07:13) : ASK 100 AAPL @ $189.23)),
#  (1,
#   OrderAcceptedMsg(message_id=95137, order=(Agent 1 @ 1970-01-01 04:07:14) : ASK 100 AAPL @ $189.26)),
#  (1,
#   OrderCancelledMsg(message_id=95138, order=(Agent 1 @ 1970-01-01 04:07:14) : ASK 100 AAPL @ $189.26)),
#  (1,
#   OrderAcceptedMsg(message_id=95139, order=(Agent 1 @ 1970-01-01 04:07:15) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderCancelledMsg(message_id=95140, order=(Agent 1 @ 1970-01-01 04:07:15) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderAcceptedMsg(message_id=95141, order=(Agent 1 @ 1970-01-01 04:07:18) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderCancelledMsg(message_id=95142, order=(Agent 1 @ 1970-01-01 04:07:18) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderAcceptedMsg(message_id=95143, order=(Agent 1 @ 1970-01-01 04:07:19) : ASK 100 AAPL @ $189.34)),
#  (1,
#   OrderCancelledMsg(message_id=95144, order=(Agent 1 @ 1970-01-01 04:07:19) : ASK 100 AAPL @ $189.34)),
#  (1,
#   OrderAcceptedMsg(message_id=95145, order=(Agent 1 @ 1970-01-01 04:07:20) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderCancelledMsg(message_id=95146, order=(Agent 1 @ 1970-01-01 04:07:20) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderAcceptedMsg(message_id=95147, order=(Agent 1 @ 1970-01-01 04:07:20) : ASK 100 AAPL @ $189.28)),
#  (1,
#   OrderCancelledMsg(message_id=95148, order=(Agent 1 @ 1970-01-01 04:07:20) : ASK 100 AAPL @ $189.28)),
#  (1,
#   OrderAcceptedMsg(message_id=95149, order=(Agent 1 @ 1970-01-01 04:07:21) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderCancelledMsg(message_id=95150, order=(Agent 1 @ 1970-01-01 04:07:21) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderAcceptedMsg(message_id=95151, order=(Agent 1 @ 1970-01-01 04:07:22) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderCancelledMsg(message_id=95152, order=(Agent 1 @ 1970-01-01 04:07:22) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderAcceptedMsg(message_id=95153, order=(Agent 1 @ 1970-01-01 04:07:24) : ASK 100 AAPL @ $189.23)),
#  (1,
#   OrderCancelledMsg(message_id=95154, order=(Agent 1 @ 1970-01-01 04:07:24) : ASK 100 AAPL @ $189.23)),
#  (1,
#   OrderAcceptedMsg(message_id=95155, order=(Agent 1 @ 1970-01-01 04:07:24) : ASK 100 AAPL @ $189.26)),
#  (1,
#   OrderCancelledMsg(message_id=95156, order=(Agent 1 @ 1970-01-01 04:07:24) : ASK 100 AAPL @ $189.26)),
#  (1,
#   OrderAcceptedMsg(message_id=95157, order=(Agent 1 @ 1970-01-01 04:07:25) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderCancelledMsg(message_id=95158, order=(Agent 1 @ 1970-01-01 04:07:25) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderAcceptedMsg(message_id=95159, order=(Agent 1 @ 1970-01-01 04:07:25) : ASK 100 AAPL @ $189.27)),
#  (1,
#   OrderAcceptedMsg(message_id=95160, order=(Agent 1 @ 1970-01-01 04:07:26) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderCancelledMsg(message_id=95161, order=(Agent 1 @ 1970-01-01 04:07:25) : ASK 100 AAPL @ $189.27)),
#  (1,
#   OrderCancelledMsg(message_id=95162, order=(Agent 1 @ 1970-01-01 04:07:26) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderAcceptedMsg(message_id=95163, order=(Agent 1 @ 1970-01-01 04:07:26) : ASK 100 AAPL @ $189.28)),
#  (1,
#   OrderCancelledMsg(message_id=95164, order=(Agent 1 @ 1970-01-01 04:07:11) : BID 100 AAPL @ $188.03)),
#  (1,
#   OrderAcceptedMsg(message_id=95165, order=(Agent 1 @ 1970-01-01 04:07:27) : BID 100 AAPL @ $188.04)),
#  (1,
#   OrderCancelledMsg(message_id=95166, order=(Agent 1 @ 1970-01-01 04:07:26) : ASK 100 AAPL @ $189.28)),
#  (1,
#   OrderAcceptedMsg(message_id=95167, order=(Agent 1 @ 1970-01-01 04:07:27) : ASK 100 AAPL @ $189.26)),
#  (1,
#   OrderCancelledMsg(message_id=95168, order=(Agent 1 @ 1970-01-01 04:07:27) : ASK 100 AAPL @ $189.26)),
#  (1,
#   OrderAcceptedMsg(message_id=95169, order=(Agent 1 @ 1970-01-01 04:07:28) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderCancelledMsg(message_id=95170, order=(Agent 1 @ 1970-01-01 04:07:27) : BID 100 AAPL @ $188.04)),
#  (1,
#   OrderAcceptedMsg(message_id=95171, order=(Agent 1 @ 1970-01-01 04:07:28) : BID 100 AAPL @ $188.06)),
#  (1,
#   OrderCancelledMsg(message_id=95172, order=(Agent 1 @ 1970-01-01 04:07:28) : BID 100 AAPL @ $188.06)),
#  (1,
#   OrderAcceptedMsg(message_id=95173, order=(Agent 1 @ 1970-01-01 04:07:29) : BID 100 AAPL @ $188.16)),
#  (1,
#   OrderCancelledMsg(message_id=95174, order=(Agent 1 @ 1970-01-01 04:07:29) : BID 100 AAPL @ $188.16)),
#  (1,
#   OrderAcceptedMsg(message_id=95175, order=(Agent 1 @ 1970-01-01 04:07:29) : BID 100 AAPL @ $187.94)),
#  (1,
#   OrderCancelledMsg(message_id=95176, order=(Agent 1 @ 1970-01-01 04:07:28) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderAcceptedMsg(message_id=95177, order=(Agent 1 @ 1970-01-01 04:07:29) : ASK 100 AAPL @ $189.29)),
#  (1,
#   OrderCancelledMsg(message_id=95178, order=(Agent 1 @ 1970-01-01 04:07:29) : BID 100 AAPL @ $187.94)),
#  (1,
#   OrderAcceptedMsg(message_id=95179, order=(Agent 1 @ 1970-01-01 04:07:30) : BID 100 AAPL @ $187.96)),
#  (1,
#   OrderCancelledMsg(message_id=95180, order=(Agent 1 @ 1970-01-01 04:07:29) : ASK 100 AAPL @ $189.29)),
#  (1,
#   OrderAcceptedMsg(message_id=95181, order=(Agent 1 @ 1970-01-01 04:07:30) : ASK 100 AAPL @ $189.27)),
#  (1,
#   OrderCancelledMsg(message_id=95182, order=(Agent 1 @ 1970-01-01 04:07:30) : BID 100 AAPL @ $187.96)),
#  (1,
#   OrderAcceptedMsg(message_id=95183, order=(Agent 1 @ 1970-01-01 04:07:30) : BID 100 AAPL @ $188.15)),
#  (1,
#   OrderCancelledMsg(message_id=95184, order=(Agent 1 @ 1970-01-01 04:07:30) : BID 100 AAPL @ $188.15)),
#  (1,
#   OrderAcceptedMsg(message_id=95185, order=(Agent 1 @ 1970-01-01 04:07:31) : BID 100 AAPL @ $187.89)),
#  (1,
#   OrderCancelledMsg(message_id=95186, order=(Agent 1 @ 1970-01-01 04:07:31) : BID 100 AAPL @ $187.89)),
#  (1,
#   OrderAcceptedMsg(message_id=95187, order=(Agent 1 @ 1970-01-01 04:07:31) : ASK 100 AAPL @ $189.26)),
#  (1,
#   OrderCancelledMsg(message_id=95188, order=(Agent 1 @ 1970-01-01 04:07:30) : ASK 100 AAPL @ $189.27)),
#  (1,
#   OrderAcceptedMsg(message_id=95189, order=(Agent 1 @ 1970-01-01 04:07:31) : BID 100 AAPL @ $187.94)),
#  (1,
#   OrderCancelledMsg(message_id=95190, order=(Agent 1 @ 1970-01-01 04:07:31) : ASK 100 AAPL @ $189.26)),
#  (1,
#   OrderCancelledMsg(message_id=95191, order=(Agent 1 @ 1970-01-01 04:07:31) : BID 100 AAPL @ $187.94)),
#  (1,
#   OrderAcceptedMsg(message_id=95192, order=(Agent 1 @ 1970-01-01 04:07:32) : BID 100 AAPL @ $188.05)),
#  (1,
#   OrderAcceptedMsg(message_id=95193, order=(Agent 1 @ 1970-01-01 04:07:32) : ASK 100 AAPL @ $189.31)),
#  (1,
#   OrderCancelledMsg(message_id=95194, order=(Agent 1 @ 1970-01-01 04:07:32) : BID 100 AAPL @ $188.05)),
#  (1,
#   OrderAcceptedMsg(message_id=95195, order=(Agent 1 @ 1970-01-01 04:07:33) : BID 100 AAPL @ $188.08)),
#  (1,
#   OrderCancelledMsg(message_id=95196, order=(Agent 1 @ 1970-01-01 04:07:32) : ASK 100 AAPL @ $189.31)),
#  (1,
#   OrderAcceptedMsg(message_id=95197, order=(Agent 1 @ 1970-01-01 04:07:33) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderCancelledMsg(message_id=95198, order=(Agent 1 @ 1970-01-01 04:07:33) : BID 100 AAPL @ $188.08)),
#  (1,
#   OrderCancelledMsg(message_id=95199, order=(Agent 1 @ 1970-01-01 04:07:33) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderAcceptedMsg(message_id=95200, order=(Agent 1 @ 1970-01-01 04:07:33) : BID 100 AAPL @ $187.94)),
#  (1,
#   OrderAcceptedMsg(message_id=95201, order=(Agent 1 @ 1970-01-01 04:07:33) : ASK 100 AAPL @ $189.29)),
#  (1,
#   OrderCancelledMsg(message_id=95202, order=(Agent 1 @ 1970-01-01 04:07:33) : BID 100 AAPL @ $187.94)),
#  (1,
#   OrderAcceptedMsg(message_id=95203, order=(Agent 1 @ 1970-01-01 04:07:34) : ASK 100 AAPL @ $189.28)),
#  (1,
#   OrderCancelledMsg(message_id=95204, order=(Agent 1 @ 1970-01-01 04:07:33) : ASK 100 AAPL @ $189.29)),
#  (1,
#   OrderAcceptedMsg(message_id=95205, order=(Agent 1 @ 1970-01-01 04:07:34) : BID 100 AAPL @ $188.00)),
#  (1,
#   OrderCancelledMsg(message_id=95206, order=(Agent 1 @ 1970-01-01 04:07:34) : BID 100 AAPL @ $188.00)),
#  (1,
#   OrderAcceptedMsg(message_id=95207, order=(Agent 1 @ 1970-01-01 04:07:34) : BID 100 AAPL @ $188.10)),
#  (1,
#   OrderCancelledMsg(message_id=95208, order=(Agent 1 @ 1970-01-01 04:07:34) : ASK 100 AAPL @ $189.28)),
#  (1,
#   OrderAcceptedMsg(message_id=95209, order=(Agent 1 @ 1970-01-01 04:07:34) : ASK 100 AAPL @ $189.26)),
#  (1,
#   OrderCancelledMsg(message_id=95210, order=(Agent 1 @ 1970-01-01 04:07:34) : BID 100 AAPL @ $188.10)),
#  (1,
#   OrderCancelledMsg(message_id=95211, order=(Agent 1 @ 1970-01-01 04:07:34) : ASK 100 AAPL @ $189.26)),
#  (1,
#   OrderAcceptedMsg(message_id=95212, order=(Agent 1 @ 1970-01-01 04:07:35) : BID 100 AAPL @ $188.07)),
#  (1,
#   OrderAcceptedMsg(message_id=95213, order=(Agent 1 @ 1970-01-01 04:07:35) : ASK 100 AAPL @ $189.29)),
#  (1,
#   OrderCancelledMsg(message_id=95214, order=(Agent 1 @ 1970-01-01 04:07:35) : BID 100 AAPL @ $188.07)),
#  (1,
#   OrderAcceptedMsg(message_id=95215, order=(Agent 1 @ 1970-01-01 04:07:35) : BID 100 AAPL @ $188.13)),
#  (1,
#   OrderCancelledMsg(message_id=95216, order=(Agent 1 @ 1970-01-01 04:07:35) : ASK 100 AAPL @ $189.29)),
#  (1,
#   OrderAcceptedMsg(message_id=95217, order=(Agent 1 @ 1970-01-01 04:07:36) : ASK 100 AAPL @ $189.28)),
#  (1,
#   OrderCancelledMsg(message_id=95218, order=(Agent 1 @ 1970-01-01 04:07:35) : BID 100 AAPL @ $188.13)),
#  (1,
#   OrderAcceptedMsg(message_id=95219, order=(Agent 1 @ 1970-01-01 04:07:36) : BID 100 AAPL @ $188.01)),
#  (1,
#   OrderCancelledMsg(message_id=95220, order=(Agent 1 @ 1970-01-01 04:07:36) : ASK 100 AAPL @ $189.28)),
#  (1,
#   OrderAcceptedMsg(message_id=95221, order=(Agent 1 @ 1970-01-01 04:07:36) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderCancelledMsg(message_id=95222, order=(Agent 1 @ 1970-01-01 04:07:36) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderCancelledMsg(message_id=95223, order=(Agent 1 @ 1970-01-01 04:07:36) : BID 100 AAPL @ $188.01)),
#  (1,
#   OrderAcceptedMsg(message_id=95224, order=(Agent 1 @ 1970-01-01 04:07:37) : ASK 100 AAPL @ $189.28)),
#  (1,
#   OrderAcceptedMsg(message_id=95225, order=(Agent 1 @ 1970-01-01 04:07:37) : BID 100 AAPL @ $188.03)),
#  (1,
#   OrderCancelledMsg(message_id=95226, order=(Agent 1 @ 1970-01-01 04:07:37) : BID 100 AAPL @ $188.03)),
#  (1,
#   OrderAcceptedMsg(message_id=95227, order=(Agent 1 @ 1970-01-01 04:07:37) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderCancelledMsg(message_id=95228, order=(Agent 1 @ 1970-01-01 04:07:37) : ASK 100 AAPL @ $189.28)),
#  (1,
#   OrderAcceptedMsg(message_id=95229, order=(Agent 1 @ 1970-01-01 04:07:37) : BID 100 AAPL @ $188.07)),
#  (1,
#   OrderCancelledMsg(message_id=95230, order=(Agent 1 @ 1970-01-01 04:07:37) : BID 100 AAPL @ $188.07)),
#  (1,
#   OrderAcceptedMsg(message_id=95231, order=(Agent 1 @ 1970-01-01 04:07:38) : BID 100 AAPL @ $187.87)),
#  (1,
#   OrderCancelledMsg(message_id=95232, order=(Agent 1 @ 1970-01-01 04:07:37) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderAcceptedMsg(message_id=95233, order=(Agent 1 @ 1970-01-01 04:07:38) : ASK 100 AAPL @ $189.29)),
#  (1,
#   OrderCancelledMsg(message_id=95234, order=(Agent 1 @ 1970-01-01 04:07:38) : BID 100 AAPL @ $187.87)),
#  (1,
#   OrderAcceptedMsg(message_id=95235, order=(Agent 1 @ 1970-01-01 04:07:38) : BID 100 AAPL @ $188.00)),
#  (1,
#   OrderCancelledMsg(message_id=95236, order=(Agent 1 @ 1970-01-01 04:07:38) : ASK 100 AAPL @ $189.29)),
#  (1,
#   OrderAcceptedMsg(message_id=95237, order=(Agent 1 @ 1970-01-01 04:07:39) : ASK 100 AAPL @ $189.28)),
#  (1,
#   OrderCancelledMsg(message_id=95238, order=(Agent 1 @ 1970-01-01 04:07:38) : BID 100 AAPL @ $188.00)),
#  (1,
#   OrderAcceptedMsg(message_id=95239, order=(Agent 1 @ 1970-01-01 04:07:39) : BID 100 AAPL @ $188.01)),
#  (1,
#   OrderCancelledMsg(message_id=95240, order=(Agent 1 @ 1970-01-01 04:07:39) : ASK 100 AAPL @ $189.28)),
#  (1,
#   OrderAcceptedMsg(message_id=95241, order=(Agent 1 @ 1970-01-01 04:07:39) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderCancelledMsg(message_id=95242, order=(Agent 1 @ 1970-01-01 04:07:39) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderCancelledMsg(message_id=95243, order=(Agent 1 @ 1970-01-01 04:07:39) : BID 100 AAPL @ $188.01)),
#  (1,
#   OrderAcceptedMsg(message_id=95244, order=(Agent 1 @ 1970-01-01 04:07:39) : BID 100 AAPL @ $188.09)),
#  (1,
#   OrderCancelledMsg(message_id=95245, order=(Agent 1 @ 1970-01-01 04:07:39) : BID 100 AAPL @ $188.09)),
#  (1,
#   OrderAcceptedMsg(message_id=95246, order=(Agent 1 @ 1970-01-01 04:07:40) : ASK 100 AAPL @ $189.29)),
#  (1,
#   OrderAcceptedMsg(message_id=95247, order=(Agent 1 @ 1970-01-01 04:07:40) : BID 100 AAPL @ $188.11)),
#  (1,
#   OrderCancelledMsg(message_id=95248, order=(Agent 1 @ 1970-01-01 04:07:40) : BID 100 AAPL @ $188.11)),
#  (1,
#   OrderCancelledMsg(message_id=95249, order=(Agent 1 @ 1970-01-01 04:07:40) : ASK 100 AAPL @ $189.29)),
#  (1,
#   OrderAcceptedMsg(message_id=95250, order=(Agent 1 @ 1970-01-01 04:07:40) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderAcceptedMsg(message_id=95251, order=(Agent 1 @ 1970-01-01 04:07:40) : BID 100 AAPL @ $187.99)),
#  (1,
#   OrderCancelledMsg(message_id=95252, order=(Agent 1 @ 1970-01-01 04:07:40) : BID 100 AAPL @ $187.99)),
#  (1,
#   OrderAcceptedMsg(message_id=95253, order=(Agent 1 @ 1970-01-01 04:07:41) : BID 100 AAPL @ $188.12)),
#  (1,
#   OrderCancelledMsg(message_id=95254, order=(Agent 1 @ 1970-01-01 04:07:41) : BID 100 AAPL @ $188.12)),
#  (1,
#   OrderAcceptedMsg(message_id=95255, order=(Agent 1 @ 1970-01-01 04:07:42) : BID 100 AAPL @ $188.15)),
#  (1,
#   OrderCancelledMsg(message_id=95256, order=(Agent 1 @ 1970-01-01 04:07:42) : BID 100 AAPL @ $188.15)),
#  (1,
#   OrderAcceptedMsg(message_id=95257, order=(Agent 1 @ 1970-01-01 04:07:42) : BID 100 AAPL @ $188.09)),
#  (1,
#   OrderCancelledMsg(message_id=95258, order=(Agent 1 @ 1970-01-01 04:07:40) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderAcceptedMsg(message_id=95259, order=(Agent 1 @ 1970-01-01 04:07:42) : ASK 100 AAPL @ $189.29)),
#  (1,
#   OrderCancelledMsg(message_id=95260, order=(Agent 1 @ 1970-01-01 04:07:42) : BID 100 AAPL @ $188.09)),
#  (1,
#   OrderAcceptedMsg(message_id=95261, order=(Agent 1 @ 1970-01-01 04:07:43) : BID 100 AAPL @ $188.14)),
#  (1,
#   OrderCancelledMsg(message_id=95262, order=(Agent 1 @ 1970-01-01 04:07:42) : ASK 100 AAPL @ $189.29)),
#  (1,
#   OrderAcceptedMsg(message_id=95263, order=(Agent 1 @ 1970-01-01 04:07:43) : ASK 100 AAPL @ $189.27)),
#  (1,
#   OrderCancelledMsg(message_id=95264, order=(Agent 1 @ 1970-01-01 04:07:43) : BID 100 AAPL @ $188.14)),
#  (1,
#   OrderAcceptedMsg(message_id=95265, order=(Agent 1 @ 1970-01-01 04:07:43) : BID 100 AAPL @ $187.88)),
#  (1,
#   OrderCancelledMsg(message_id=95266, order=(Agent 1 @ 1970-01-01 04:07:43) : ASK 100 AAPL @ $189.27)),
#  (1,
#   OrderAcceptedMsg(message_id=95267, order=(Agent 1 @ 1970-01-01 04:07:43) : ASK 100 AAPL @ $189.26)),
#  (1,
#   OrderCancelledMsg(message_id=95268, order=(Agent 1 @ 1970-01-01 04:07:43) : BID 100 AAPL @ $187.88)),
#  (1,
#   OrderAcceptedMsg(message_id=95269, order=(Agent 1 @ 1970-01-01 04:07:44) : BID 100 AAPL @ $187.97)),
#  (1,
#   OrderCancelledMsg(message_id=95270, order=(Agent 1 @ 1970-01-01 04:07:43) : ASK 100 AAPL @ $189.26)),
#  (1,
#   OrderAcceptedMsg(message_id=95271, order=(Agent 1 @ 1970-01-01 04:07:44) : ASK 100 AAPL @ $189.30)),
#  (1,
#   OrderCancelledMsg(message_id=95272, order=(Agent 1 @ 1970-01-01 04:07:44) : BID 100 AAPL @ $187.97)),
#  (1,
#   OrderCancelledMsg(message_id=95273, order=(Agent 1 @ 1970-01-01 04:07:44) : ASK 100 AAPL @ $189.30)),
#  (1,
#   OrderAcceptedMsg(message_id=95274, order=(Agent 1 @ 1970-01-01 04:07:45) : BID 100 AAPL @ $188.04)),
#  (1,
#   OrderAcceptedMsg(message_id=95275, order=(Agent 1 @ 1970-01-01 04:07:45) : ASK 100 AAPL @ $189.28)),
#  (1,
#   OrderCancelledMsg(message_id=95276, order=(Agent 1 @ 1970-01-01 04:07:45) : BID 100 AAPL @ $188.04)),
#  (1,
#   OrderAcceptedMsg(message_id=95277, order=(Agent 1 @ 1970-01-01 04:07:45) : BID 100 AAPL @ $188.08)),
#  (1,
#   OrderCancelledMsg(message_id=95278, order=(Agent 1 @ 1970-01-01 04:07:45) : ASK 100 AAPL @ $189.28)),
#  (1,
#   OrderAcceptedMsg(message_id=95279, order=(Agent 1 @ 1970-01-01 04:07:46) : ASK 100 AAPL @ $189.27)),
#  (1,
#   OrderCancelledMsg(message_id=95280, order=(Agent 1 @ 1970-01-01 04:07:45) : BID 100 AAPL @ $188.08)),
#  (1,
#   OrderAcceptedMsg(message_id=95281, order=(Agent 1 @ 1970-01-01 04:07:46) : BID 100 AAPL @ $187.87)),
#  (1,
#   OrderCancelledMsg(message_id=95282, order=(Agent 1 @ 1970-01-01 04:07:46) : BID 100 AAPL @ $187.87)),
#  (1,
#   OrderAcceptedMsg(message_id=95283, order=(Agent 1 @ 1970-01-01 04:07:47) : ASK 100 AAPL @ $189.26)),
#  (1,
#   OrderCancelledMsg(message_id=95284, order=(Agent 1 @ 1970-01-01 04:07:46) : ASK 100 AAPL @ $189.27)),
#  (1,
#   OrderAcceptedMsg(message_id=95285, order=(Agent 1 @ 1970-01-01 04:07:47) : BID 100 AAPL @ $187.96)),
#  (1,
#   OrderCancelledMsg(message_id=95286, order=(Agent 1 @ 1970-01-01 04:07:47) : BID 100 AAPL @ $187.96)),
#  (1,
#   OrderAcceptedMsg(message_id=95287, order=(Agent 1 @ 1970-01-01 04:07:47) : BID 100 AAPL @ $187.99)),
#  (1,
#   OrderCancelledMsg(message_id=95288, order=(Agent 1 @ 1970-01-01 04:07:47) : ASK 100 AAPL @ $189.26)),
#  (1,
#   OrderAcceptedMsg(message_id=95289, order=(Agent 1 @ 1970-01-01 04:07:47) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderCancelledMsg(message_id=95290, order=(Agent 1 @ 1970-01-01 04:07:47) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderCancelledMsg(message_id=95291, order=(Agent 1 @ 1970-01-01 04:07:47) : BID 100 AAPL @ $187.99)),
#  (1,
#   OrderAcceptedMsg(message_id=95292, order=(Agent 1 @ 1970-01-01 04:07:48) : BID 100 AAPL @ $188.03)),
#  (1,
#   OrderAcceptedMsg(message_id=95293, order=(Agent 1 @ 1970-01-01 04:07:48) : ASK 100 AAPL @ $189.29)),
#  (1,
#   OrderCancelledMsg(message_id=95294, order=(Agent 1 @ 1970-01-01 04:07:48) : BID 100 AAPL @ $188.03)),
#  (1,
#   OrderAcceptedMsg(message_id=95295, order=(Agent 1 @ 1970-01-01 04:07:49) : BID 100 AAPL @ $188.04)),
#  (1,
#   OrderCancelledMsg(message_id=95296, order=(Agent 1 @ 1970-01-01 04:07:48) : ASK 100 AAPL @ $189.29)),
#  (1,
#   OrderAcceptedMsg(message_id=95297, order=(Agent 1 @ 1970-01-01 04:07:49) : ASK 100 AAPL @ $189.28)),
#  (1,
#   OrderCancelledMsg(message_id=95298, order=(Agent 1 @ 1970-01-01 04:07:49) : BID 100 AAPL @ $188.04)),
#  (1,
#   OrderAcceptedMsg(message_id=95299, order=(Agent 1 @ 1970-01-01 04:07:50) : BID 100 AAPL @ $188.06)),
#  (1,
#   OrderCancelledMsg(message_id=95300, order=(Agent 1 @ 1970-01-01 04:07:49) : ASK 100 AAPL @ $189.28)),
#  (1,
#   OrderAcceptedMsg(message_id=95301, order=(Agent 1 @ 1970-01-01 04:07:50) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderCancelledMsg(message_id=95302, order=(Agent 1 @ 1970-01-01 04:07:50) : BID 100 AAPL @ $188.06)),
#  (1,
#   OrderAcceptedMsg(message_id=95303, order=(Agent 1 @ 1970-01-01 04:07:50) : BID 100 AAPL @ $188.02)),
#  (1,
#   OrderCancelledMsg(message_id=95304, order=(Agent 1 @ 1970-01-01 04:07:50) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderAcceptedMsg(message_id=95305, order=(Agent 1 @ 1970-01-01 04:07:51) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderCancelledMsg(message_id=95306, order=(Agent 1 @ 1970-01-01 04:07:51) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderAcceptedMsg(message_id=95307, order=(Agent 1 @ 1970-01-01 04:07:52) : ASK 100 AAPL @ $189.29)),
#  (1,
#   OrderCancelledMsg(message_id=95308, order=(Agent 1 @ 1970-01-01 04:07:52) : ASK 100 AAPL @ $189.29)),
#  (1,
#   OrderAcceptedMsg(message_id=95309, order=(Agent 1 @ 1970-01-01 04:07:53) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderCancelledMsg(message_id=95310, order=(Agent 1 @ 1970-01-01 04:07:53) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderAcceptedMsg(message_id=95311, order=(Agent 1 @ 1970-01-01 04:07:54) : ASK 100 AAPL @ $189.29)),
#  (1,
#   OrderCancelledMsg(message_id=95312, order=(Agent 1 @ 1970-01-01 04:07:54) : ASK 100 AAPL @ $189.29)),
#  (1,
#   OrderAcceptedMsg(message_id=95313, order=(Agent 1 @ 1970-01-01 04:07:55) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderCancelledMsg(message_id=95314, order=(Agent 1 @ 1970-01-01 04:07:55) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderAcceptedMsg(message_id=95315, order=(Agent 1 @ 1970-01-01 04:07:57) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderCancelledMsg(message_id=95316, order=(Agent 1 @ 1970-01-01 04:07:57) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderAcceptedMsg(message_id=95317, order=(Agent 1 @ 1970-01-01 04:07:57) : ASK 100 AAPL @ $189.29)),
#  (1,
#   OrderCancelledMsg(message_id=95318, order=(Agent 1 @ 1970-01-01 04:07:57) : ASK 100 AAPL @ $189.29)),
#  (1,
#   OrderAcceptedMsg(message_id=95319, order=(Agent 1 @ 1970-01-01 04:07:58) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderCancelledMsg(message_id=95320, order=(Agent 1 @ 1970-01-01 04:07:58) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderAcceptedMsg(message_id=95321, order=(Agent 1 @ 1970-01-01 04:08:01) : ASK 100 AAPL @ $189.29)),
#  (1,
#   OrderCancelledMsg(message_id=95322, order=(Agent 1 @ 1970-01-01 04:08:01) : ASK 100 AAPL @ $189.29)),
#  (1,
#   OrderAcceptedMsg(message_id=95323, order=(Agent 1 @ 1970-01-01 04:08:02) : ASK 100 AAPL @ $189.26)),
#  (1,
#   OrderCancelledMsg(message_id=95324, order=(Agent 1 @ 1970-01-01 04:08:02) : ASK 100 AAPL @ $189.26)),
#  (1,
#   OrderAcceptedMsg(message_id=95325, order=(Agent 1 @ 1970-01-01 04:08:02) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderCancelledMsg(message_id=95326, order=(Agent 1 @ 1970-01-01 04:08:02) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderAcceptedMsg(message_id=95327, order=(Agent 1 @ 1970-01-01 04:08:03) : ASK 100 AAPL @ $189.29)),
#  (1,
#   OrderCancelledMsg(message_id=95328, order=(Agent 1 @ 1970-01-01 04:08:03) : ASK 100 AAPL @ $189.29)),
#  (1,
#   OrderAcceptedMsg(message_id=95329, order=(Agent 1 @ 1970-01-01 04:08:03) : ASK 100 AAPL @ $189.26)),
#  (1,
#   OrderAcceptedMsg(message_id=95330, order=(Agent 1 @ 1970-01-01 04:08:06) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderCancelledMsg(message_id=95331, order=(Agent 1 @ 1970-01-01 04:08:03) : ASK 100 AAPL @ $189.26)),
#  (1,
#   OrderCancelledMsg(message_id=95332, order=(Agent 1 @ 1970-01-01 04:08:06) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderAcceptedMsg(message_id=95333, order=(Agent 1 @ 1970-01-01 04:08:07) : ASK 100 AAPL @ $189.28)),
#  (1,
#   OrderCancelledMsg(message_id=95334, order=(Agent 1 @ 1970-01-01 04:08:07) : ASK 100 AAPL @ $189.28)),
#  (1,
#   OrderAcceptedMsg(message_id=95335, order=(Agent 1 @ 1970-01-01 04:08:08) : ASK 100 AAPL @ $189.27)),
#  (1,
#   OrderCancelledMsg(message_id=95336, order=(Agent 1 @ 1970-01-01 04:08:08) : ASK 100 AAPL @ $189.27)),
#  (1,
#   OrderAcceptedMsg(message_id=95337, order=(Agent 1 @ 1970-01-01 04:08:09) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderCancelledMsg(message_id=95338, order=(Agent 1 @ 1970-01-01 04:07:50) : BID 100 AAPL @ $188.02)),
#  (1,
#   OrderAcceptedMsg(message_id=95339, order=(Agent 1 @ 1970-01-01 04:08:12) : BID 100 AAPL @ $188.03)),
#  (1,
#   OrderCancelledMsg(message_id=95340, order=(Agent 1 @ 1970-01-01 04:08:09) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderAcceptedMsg(message_id=95341, order=(Agent 1 @ 1970-01-01 04:08:12) : ASK 100 AAPL @ $189.23)),
#  (1,
#   OrderCancelledMsg(message_id=95342, order=(Agent 1 @ 1970-01-01 04:08:12) : ASK 100 AAPL @ $189.23)),
#  (1,
#   OrderAcceptedMsg(message_id=95343, order=(Agent 1 @ 1970-01-01 04:08:13) : ASK 100 AAPL @ $189.28)),
#  (1,
#   OrderAcceptedMsg(message_id=95344, order=(Agent 1 @ 1970-01-01 04:08:13) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderCancelledMsg(message_id=95345, order=(Agent 1 @ 1970-01-01 04:08:13) : ASK 100 AAPL @ $189.28)),
#  (1,
#   OrderCancelledMsg(message_id=95346, order=(Agent 1 @ 1970-01-01 04:08:13) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderAcceptedMsg(message_id=95347, order=(Agent 1 @ 1970-01-01 04:08:15) : ASK 100 AAPL @ $189.30)),
#  (1,
#   OrderCancelledMsg(message_id=95348, order=(Agent 1 @ 1970-01-01 04:08:15) : ASK 100 AAPL @ $189.30)),
#  (1,
#   OrderAcceptedMsg(message_id=95349, order=(Agent 1 @ 1970-01-01 04:08:16) : ASK 100 AAPL @ $189.28)),
#  (1,
#   OrderAcceptedMsg(message_id=95350, order=(Agent 1 @ 1970-01-01 04:08:16) : BID 888 AAPL @ $188.63)),
#  (1,
#   OrderCancelledMsg(message_id=95351, order=(Agent 1 @ 1970-01-01 04:08:16) : ASK 100 AAPL @ $189.28)),
#  (1,
#   OrderAcceptedMsg(message_id=95352, order=(Agent 1 @ 1970-01-01 04:08:16) : ASK 100 AAPL @ $189.26)),
#  (1,
#   OrderCancelledMsg(message_id=95353, order=(Agent 1 @ 1970-01-01 04:08:12) : BID 100 AAPL @ $188.03)),
#  (1,
# ...
#  (1,
#   OrderAcceptedMsg(message_id=95839, order=(Agent 1 @ 1970-01-01 04:17:52) : ASK 100 AAPL @ $189.13)),
#  (1,
#   OrderCancelledMsg(message_id=95840, order=(Agent 1 @ 1970-01-01 04:17:52) : ASK 100 AAPL @ $189.13)),
#  (1,
#   OrderAcceptedMsg(message_id=95841, order=(Agent 1 @ 1970-01-01 04:17:53) : ASK 100 AAPL @ $189.11)),
#  (1,
#   OrderCancelledMsg(message_id=95842, order=(Agent 1 @ 1970-01-01 04:17:53) : ASK 100 AAPL @ $189.11)),
#  (1,
#   OrderAcceptedMsg(message_id=95843, order=(Agent 1 @ 1970-01-01 04:17:53) : ASK 100 AAPL @ $189.23)),
#  (1,
#   OrderCancelledMsg(message_id=95844, order=(Agent 1 @ 1970-01-01 04:17:53) : ASK 100 AAPL @ $189.23)),
#  (1,
#   OrderAcceptedMsg(message_id=95845, order=(Agent 1 @ 1970-01-01 04:17:58) : ASK 100 AAPL @ $189.27)),
#  (1,
#   OrderCancelledMsg(message_id=95846, order=(Agent 1 @ 1970-01-01 04:17:58) : ASK 100 AAPL @ $189.27)),
#  (1,
#   OrderAcceptedMsg(message_id=95847, order=(Agent 1 @ 1970-01-01 04:17:59) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderCancelledMsg(message_id=95848, order=(Agent 1 @ 1970-01-01 04:17:59) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderAcceptedMsg(message_id=95849, order=(Agent 1 @ 1970-01-01 04:18:16) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderCancelledMsg(message_id=95850, order=(Agent 1 @ 1970-01-01 04:18:16) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderAcceptedMsg(message_id=95851, order=(Agent 1 @ 1970-01-01 04:18:27) : ASK 100 AAPL @ $189.23)),
#  (1,
#   OrderCancelledMsg(message_id=95852, order=(Agent 1 @ 1970-01-01 04:18:27) : ASK 100 AAPL @ $189.23)),
#  (1,
#   OrderAcceptedMsg(message_id=95853, order=(Agent 1 @ 1970-01-01 04:18:30) : ASK 100 AAPL @ $189.22)),
#  (1,
#   OrderCancelledMsg(message_id=95854, order=(Agent 1 @ 1970-01-01 04:17:17) : BID 100 AAPL @ $188.34)),
#  (1,
#   OrderAcceptedMsg(message_id=95855, order=(Agent 1 @ 1970-01-01 04:18:33) : BID 100 AAPL @ $188.30)),
#  (1,
#   OrderCancelledMsg(message_id=95856, order=(Agent 1 @ 1970-01-01 04:18:33) : BID 100 AAPL @ $188.30)),
#  (1,
#   OrderAcceptedMsg(message_id=95857, order=(Agent 1 @ 1970-01-01 04:18:34) : BID 100 AAPL @ $188.31)),
#  (1,
#   OrderAcceptedMsg(message_id=95858, order=(Agent 1 @ 1970-01-01 04:18:57) : BID 100 AAPL @ $188.01)),
#  (1,
#   OrderAcceptedMsg(message_id=95859, order=(Agent 1 @ 1970-01-01 04:19:05) : BID 100 AAPL @ $187.51)),
#  (1,
#   OrderAcceptedMsg(message_id=95860, order=(Agent 1 @ 1970-01-01 04:19:12) : BID 100 AAPL @ $187.11)),
#  (1,
#   OrderCancelledMsg(message_id=95861, order=(Agent 1 @ 1970-01-01 04:18:30) : ASK 100 AAPL @ $189.22)),
#  (1,
#   OrderAcceptedMsg(message_id=95862, order=(Agent 1 @ 1970-01-01 04:19:24) : ASK 100 AAPL @ $189.21)),
#  (1,
#   OrderAcceptedMsg(message_id=95863, order=(Agent 1 @ 1970-01-01 04:19:28) : BID 150 AAPL @ $188.77)),
#  (1,
#   OrderCancelledMsg(message_id=95864, order=(Agent 1 @ 1970-01-01 04:18:34) : BID 100 AAPL @ $188.31)),
#  (1,
#   OrderAcceptedMsg(message_id=95865, order=(Agent 1 @ 1970-01-01 04:19:28) : BID 100 AAPL @ $188.32)),
#  (1,
#   OrderCancelledMsg(message_id=95866, order=(Agent 1 @ 1970-01-01 04:19:28) : BID 100 AAPL @ $188.32)),
#  (1,
#   OrderAcceptedMsg(message_id=95867, order=(Agent 1 @ 1970-01-01 04:19:29) : BID 100 AAPL @ $188.35)),
#  (1,
#   OrderCancelledMsg(message_id=95868, order=(Agent 1 @ 1970-01-01 04:19:29) : BID 100 AAPL @ $188.35)),
#  (1,
#   OrderAcceptedMsg(message_id=95869, order=(Agent 1 @ 1970-01-01 04:19:31) : BID 100 AAPL @ $188.36)),
#  (1,
#   OrderCancelledMsg(message_id=95870, order=(Agent 1 @ 1970-01-01 04:19:31) : BID 100 AAPL @ $188.36)),
#  (1,
#   OrderAcceptedMsg(message_id=95871, order=(Agent 1 @ 1970-01-01 04:19:33) : BID 100 AAPL @ $188.37)),
#  (1,
#   OrderAcceptedMsg(message_id=95872, order=(Agent 1 @ 1970-01-01 04:19:34) : BID 100 AAPL @ $188.44)),
#  (1,
#   OrderCancelledMsg(message_id=95873, order=(Agent 1 @ 1970-01-01 04:19:33) : BID 100 AAPL @ $188.37)),
#  (1,
#   OrderCancelledMsg(message_id=95874, order=(Agent 1 @ 1970-01-01 04:19:34) : BID 100 AAPL @ $188.44)),
#  (1,
#   OrderAcceptedMsg(message_id=95875, order=(Agent 1 @ 1970-01-01 04:19:40) : BID 100 AAPL @ $188.45)),
#  (1,
#   OrderCancelledMsg(message_id=95876, order=(Agent 1 @ 1970-01-01 04:19:24) : ASK 100 AAPL @ $189.21)),
#  (1,
#   OrderAcceptedMsg(message_id=95877, order=(Agent 1 @ 1970-01-01 04:19:40) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderCancelledMsg(message_id=95878, order=(Agent 1 @ 1970-01-01 04:19:40) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderAcceptedMsg(message_id=95879, order=(Agent 1 @ 1970-01-01 04:19:41) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderCancelledMsg(message_id=95880, order=(Agent 1 @ 1970-01-01 04:19:41) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderAcceptedMsg(message_id=95881, order=(Agent 1 @ 1970-01-01 04:19:41) : ASK 100 AAPL @ $189.23)),
#  (1,
#   OrderCancelledMsg(message_id=95882, order=(Agent 1 @ 1970-01-01 04:17:04) : ASK 10 AAPL @ $189.00)),
#  (1,
#   OrderCancelledMsg(message_id=95883, order=(Agent 1 @ 1970-01-01 04:19:41) : ASK 100 AAPL @ $189.23)),
#  (1,
#   OrderAcceptedMsg(message_id=95884, order=(Agent 1 @ 1970-01-01 04:19:44) : ASK 100 AAPL @ $189.22)),
#  (1,
#   OrderAcceptedMsg(message_id=95885, order=(Agent 1 @ 1970-01-01 04:19:46) : BID 100 AAPL @ $188.41)),
#  (1,
#   OrderCancelledMsg(message_id=95886, order=(Agent 1 @ 1970-01-01 04:19:40) : BID 100 AAPL @ $188.45)),
#  (1,
#   OrderCancelledMsg(message_id=95887, order=(Agent 1 @ 1970-01-01 04:19:44) : ASK 100 AAPL @ $189.22)),
#  (1,
#   OrderAcceptedMsg(message_id=95888, order=(Agent 1 @ 1970-01-01 04:19:48) : ASK 100 AAPL @ $189.21)),
#  (1,
#   OrderCancelledMsg(message_id=95889, order=(Agent 1 @ 1970-01-01 04:19:46) : BID 100 AAPL @ $188.41)),
#  (1,
#   OrderAcceptedMsg(message_id=95890, order=(Agent 1 @ 1970-01-01 04:19:49) : BID 100 AAPL @ $188.42)),
#  (1,
#   OrderCancelledMsg(message_id=95891, order=(Agent 1 @ 1970-01-01 04:19:49) : BID 100 AAPL @ $188.42)),
#  (1,
#   OrderAcceptedMsg(message_id=95892, order=(Agent 1 @ 1970-01-01 04:19:49) : BID 100 AAPL @ $188.44)),
#  (1,
#   OrderCancelledMsg(message_id=95893, order=(Agent 1 @ 1970-01-01 04:19:49) : BID 100 AAPL @ $188.44)),
#  (1,
#   OrderAcceptedMsg(message_id=95894, order=(Agent 1 @ 1970-01-01 04:19:51) : BID 100 AAPL @ $188.40)),
#  (1,
#   OrderCancelledMsg(message_id=95895, order=(Agent 1 @ 1970-01-01 04:19:51) : BID 100 AAPL @ $188.40)),
#  (1,
#   OrderAcceptedMsg(message_id=95896, order=(Agent 1 @ 1970-01-01 04:19:52) : BID 100 AAPL @ $188.41)),
#  (1,
#   OrderCancelledMsg(message_id=95897, order=(Agent 1 @ 1970-01-01 04:19:52) : BID 100 AAPL @ $188.41)),
#  (1,
#   OrderAcceptedMsg(message_id=95898, order=(Agent 1 @ 1970-01-01 04:19:52) : BID 100 AAPL @ $188.42)),
#  (1,
#   OrderCancelledMsg(message_id=95899, order=(Agent 1 @ 1970-01-01 04:19:52) : BID 100 AAPL @ $188.42)),
#  (1,
#   OrderAcceptedMsg(message_id=95900, order=(Agent 1 @ 1970-01-01 04:19:55) : BID 100 AAPL @ $188.43)),
#  (1,
#   OrderCancelledMsg(message_id=95901, order=(Agent 1 @ 1970-01-01 04:19:55) : BID 100 AAPL @ $188.43)),
#  (1,
#   OrderAcceptedMsg(message_id=95902, order=(Agent 1 @ 1970-01-01 04:20:00) : BID 100 AAPL @ $188.33)),
#  (1,
#   OrderCancelledMsg(message_id=95903, order=(Agent 1 @ 1970-01-01 04:20:00) : BID 100 AAPL @ $188.33)),
#  (1,
#   OrderAcceptedMsg(message_id=95904, order=(Agent 1 @ 1970-01-01 04:20:00) : BID 100 AAPL @ $188.37)),
#  (1,
#   OrderCancelledMsg(message_id=95905, order=(Agent 1 @ 1970-01-01 04:19:48) : ASK 100 AAPL @ $189.21)),
#  (1,
#   OrderAcceptedMsg(message_id=95906, order=(Agent 1 @ 1970-01-01 04:20:00) : ASK 100 AAPL @ $189.20)),
#  (1,
#   OrderCancelledMsg(message_id=95907, order=(Agent 1 @ 1970-01-01 04:20:00) : BID 100 AAPL @ $188.37)),
#  (1,
#   OrderAcceptedMsg(message_id=95908, order=(Agent 1 @ 1970-01-01 04:20:01) : BID 100 AAPL @ $188.42)),
#  (1,
#   OrderCancelledMsg(message_id=95909, order=(Agent 1 @ 1970-01-01 04:20:01) : BID 100 AAPL @ $188.42)),
#  (1,
#   OrderAcceptedMsg(message_id=95910, order=(Agent 1 @ 1970-01-01 04:20:01) : BID 100 AAPL @ $188.44)),
#  (1,
#   OrderCancelledMsg(message_id=95911, order=(Agent 1 @ 1970-01-01 04:20:00) : ASK 100 AAPL @ $189.20)),
#  (1,
#   OrderAcceptedMsg(message_id=95912, order=(Agent 1 @ 1970-01-01 04:20:01) : ASK 100 AAPL @ $189.19)),
#  (1,
#   OrderCancelledMsg(message_id=95913, order=(Agent 1 @ 1970-01-01 04:20:01) : BID 100 AAPL @ $188.44)),
#  (1,
#   OrderAcceptedMsg(message_id=95914, order=(Agent 1 @ 1970-01-01 04:20:02) : BID 100 AAPL @ $188.40)),
#  (1,
#   OrderCancelledMsg(message_id=95915, order=(Agent 1 @ 1970-01-01 04:20:02) : BID 100 AAPL @ $188.40)),
#  (1,
#   OrderAcceptedMsg(message_id=95916, order=(Agent 1 @ 1970-01-01 04:20:03) : BID 100 AAPL @ $188.42)),
#  (1,
#   OrderCancelledMsg(message_id=95917, order=(Agent 1 @ 1970-01-01 04:20:03) : BID 100 AAPL @ $188.42)),
#  (1,
#   OrderAcceptedMsg(message_id=95918, order=(Agent 1 @ 1970-01-01 04:20:04) : BID 100 AAPL @ $188.43)),
#  (1,
#   OrderCancelledMsg(message_id=95919, order=(Agent 1 @ 1970-01-01 04:20:04) : BID 100 AAPL @ $188.43)),
#  (1,
#   OrderAcceptedMsg(message_id=95920, order=(Agent 1 @ 1970-01-01 04:20:07) : BID 100 AAPL @ $188.44)),
#  (1,
#   OrderCancelledMsg(message_id=95921, order=(Agent 1 @ 1970-01-01 04:20:07) : BID 100 AAPL @ $188.44)),
#  (1,
#   OrderAcceptedMsg(message_id=95922, order=(Agent 1 @ 1970-01-01 04:20:08) : BID 100 AAPL @ $188.45)),
#  (1,
#   OrderCancelledMsg(message_id=95923, order=(Agent 1 @ 1970-01-01 04:20:08) : BID 100 AAPL @ $188.45)),
#  (1,
#   OrderAcceptedMsg(message_id=95924, order=(Agent 1 @ 1970-01-01 04:20:16) : BID 100 AAPL @ $188.40)),
#  (1,
#   OrderCancelledMsg(message_id=95925, order=(Agent 1 @ 1970-01-01 04:20:16) : BID 100 AAPL @ $188.40)),
#  (1,
#   OrderAcceptedMsg(message_id=95926, order=(Agent 1 @ 1970-01-01 04:20:17) : BID 100 AAPL @ $188.43)),
#  (1,
#   OrderCancelledMsg(message_id=95927, order=(Agent 1 @ 1970-01-01 04:20:17) : BID 100 AAPL @ $188.43)),
#  (1,
#   OrderAcceptedMsg(message_id=95928, order=(Agent 1 @ 1970-01-01 04:20:18) : BID 100 AAPL @ $188.44)),
#  (1,
#   OrderCancelledMsg(message_id=95929, order=(Agent 1 @ 1970-01-01 04:20:18) : BID 100 AAPL @ $188.44)),
#  (1,
#   OrderAcceptedMsg(message_id=95930, order=(Agent 1 @ 1970-01-01 04:20:19) : BID 100 AAPL @ $188.45)),
#  (1,
#   OrderCancelledMsg(message_id=95931, order=(Agent 1 @ 1970-01-01 04:20:01) : ASK 100 AAPL @ $189.19)),
#  (1,
#   OrderAcceptedMsg(message_id=95932, order=(Agent 1 @ 1970-01-01 04:20:21) : ASK 100 AAPL @ $189.18)),
#  (1,
#   OrderCancelledMsg(message_id=95933, order=(Agent 1 @ 1970-01-01 04:19:28) : BID 150 AAPL @ $188.77)),
#  (1,
#   OrderAcceptedMsg(message_id=95934, order=(Agent 1 @ 1970-01-01 04:20:23) : BID 150 AAPL @ $188.86)),
#  (1,
#   OrderCancelledMsg(message_id=95935, order=(Agent 1 @ 1970-01-01 04:20:19) : BID 100 AAPL @ $188.45)),
#  (1,
#   OrderAcceptedMsg(message_id=95936, order=(Agent 1 @ 1970-01-01 04:20:24) : BID 100 AAPL @ $188.46)),
#  (1,
#   OrderCancelledMsg(message_id=95937, order=(Agent 1 @ 1970-01-01 04:20:24) : BID 100 AAPL @ $188.46)),
#  (1,
#   OrderAcceptedMsg(message_id=95938, order=(Agent 1 @ 1970-01-01 04:20:25) : BID 100 AAPL @ $188.50)),
#  (1,
#   OrderCancelledMsg(message_id=95939, order=(Agent 1 @ 1970-01-01 04:20:25) : BID 100 AAPL @ $188.50)),
#  (1,
#   OrderCancelledMsg(message_id=95940, order=(Agent 1 @ 1970-01-01 04:20:21) : ASK 100 AAPL @ $189.18)),
#  (1,
#   OrderAcceptedMsg(message_id=95941, order=(Agent 1 @ 1970-01-01 04:20:25) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderAcceptedMsg(message_id=95942, order=(Agent 1 @ 1970-01-01 04:20:25) : BID 100 AAPL @ $188.51)),
#  (1,
#   OrderCancelledMsg(message_id=95943, order=(Agent 1 @ 1970-01-01 04:20:25) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderAcceptedMsg(message_id=95944, order=(Agent 1 @ 1970-01-01 04:20:41) : ASK 100 AAPL @ $189.36)),
#  (1,
#   OrderCancelledMsg(message_id=95945, order=(Agent 1 @ 1970-01-01 04:20:25) : BID 100 AAPL @ $188.51)),
#  (1,
#   OrderAcceptedMsg(message_id=95946, order=(Agent 1 @ 1970-01-01 04:20:41) : BID 100 AAPL @ $188.53)),
#  (1,
#   OrderExecutedMsg(message_id=95947, order=(Agent 1 @ 1970-01-01 04:20:23) : BID 100 AAPL @ $188.86 (filled @ $188.86))),
#  (1,
#   OrderExecutedMsg(message_id=95948, order=(Agent 1 @ 1970-01-01 04:20:41) : MKT Order ASK 100 AAPL)),
#  (1,
#   OrderAcceptedMsg(message_id=95949, order=(Agent 1 @ 1970-01-01 04:20:41) : ASK 100 AAPL @ $195.01)),
#  (1,
#   OrderCancelledMsg(message_id=95950, order=(Agent 1 @ 1970-01-01 04:20:41) : ASK 100 AAPL @ $189.36)),
#  (1,
#   OrderAcceptedMsg(message_id=95951, order=(Agent 1 @ 1970-01-01 04:20:41) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderCancelledMsg(message_id=95952, order=(Agent 1 @ 1970-01-01 04:20:41) : ASK 100 AAPL @ $189.25)),
#  (1,
#   OrderAcceptedMsg(message_id=95953, order=(Agent 1 @ 1970-01-01 04:20:42) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderCancelledMsg(message_id=95954, order=(Agent 1 @ 1970-01-01 04:20:41) : BID 100 AAPL @ $188.53)),
#  (1,
#   OrderAcceptedMsg(message_id=95955, order=(Agent 1 @ 1970-01-01 04:20:53) : BID 100 AAPL @ $188.54)),
#  (1,
#   OrderCancelledMsg(message_id=95956, order=(Agent 1 @ 1970-01-01 04:20:42) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderAcceptedMsg(message_id=95957, order=(Agent 1 @ 1970-01-01 04:20:54) : ASK 100 AAPL @ $189.38)),
#  (1,
#   OrderCancelledMsg(message_id=95958, order=(Agent 1 @ 1970-01-01 04:20:54) : ASK 100 AAPL @ $189.38)),
#  (1,
#   OrderAcceptedMsg(message_id=95959, order=(Agent 1 @ 1970-01-01 04:20:54) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderCancelledMsg(message_id=95960, order=(Agent 1 @ 1970-01-01 04:20:54) : ASK 100 AAPL @ $189.24)),
#  (1,
#   OrderAcceptedMsg(message_id=95961, order=(Agent 1 @ 1970-01-01 04:20:55) : ASK 100 AAPL @ $189.21)),
#  (1,
#   OrderCancelledMsg(message_id=95962, order=(Agent 1 @ 1970-01-01 04:20:55) : ASK 100 AAPL @ $189.21)),
#  (1,
#   OrderAcceptedMsg(message_id=95963, order=(Agent 1 @ 1970-01-01 04:20:55) : ASK 100 AAPL @ $192.09)),
#  (1,
#   OrderAcceptedMsg(message_id=95964, order=(Agent 1 @ 1970-01-01 04:20:56) : ASK 100 AAPL @ $192.14)),
#  (1,
#   OrderAcceptedMsg(message_id=95965, order=(Agent 1 @ 1970-01-01 04:21:03) : ASK 80 AAPL @ $191.70)),
#  (1,
#   OrderCancelledMsg(message_id=95966, order=(Agent 1 @ 1970-01-01 04:20:55) : ASK 100 AAPL @ $192.09)),
#  (1,
#   OrderCancelledMsg(message_id=95967, order=(Agent 1 @ 1970-01-01 04:20:56) : ASK 100 AAPL @ $192.14)),
#  (1,
#   OrderAcceptedMsg(message_id=95968, order=(Agent 1 @ 1970-01-01 04:21:03) : ASK 100 AAPL @ $191.69)),
#  (1,
#   OrderAcceptedMsg(message_id=95969, order=(Agent 1 @ 1970-01-01 04:21:03) : ASK 100 AAPL @ $191.74)),
#  (1,
#   OrderExecutedMsg(message_id=95970, order=(Agent 1 @ 1970-01-01 04:20:23) : BID 22 AAPL @ $188.86 (filled @ $188.86))),
#  (1,
#   OrderExecutedMsg(message_id=95971, order=(Agent 1 @ 1970-01-01 04:21:10) : MKT Order ASK 22 AAPL)),
#  (1,
#   OrderCancelledMsg(message_id=95972, order=(Agent 1 @ 1970-01-01 04:20:41) : ASK 100 AAPL @ $195.01)),
#  (1,
#   OrderAcceptedMsg(message_id=95973, order=(Agent 1 @ 1970-01-01 04:21:10) : ASK 122 AAPL @ $195.01)),
#  (1,
#   OrderCancelledMsg(message_id=95974, order=(Agent 1 @ 1970-01-01 04:20:53) : BID 100 AAPL @ $188.54)),
#  (1,
#   OrderAcceptedMsg(message_id=95975, order=(Agent 1 @ 1970-01-01 04:21:10) : BID 100 AAPL @ $188.25)),
#  (1,
#   OrderCancelledMsg(message_id=95976, order=(Agent 1 @ 1970-01-01 04:21:10) : BID 100 AAPL @ $188.25)),
#  (1,
#   OrderAcceptedMsg(message_id=95977, order=(Agent 1 @ 1970-01-01 04:21:13) : BID 100 AAPL @ $188.26)),
#  (1,
#   OrderAcceptedMsg(message_id=95978, order=(Agent 1 @ 1970-01-01 04:21:48) : BID 100 AAPL @ $188.27)),
#  (1,
#   OrderCancelledMsg(message_id=95979, order=(Agent 1 @ 1970-01-01 04:21:13) : BID 100 AAPL @ $188.26)),
#  (1,
#   OrderExecutedMsg(message_id=95980, order=(Agent 1 @ 1970-01-01 04:20:23) : BID 28 AAPL @ $188.86 (filled @ $188.86))),
#  (1,
#   OrderExecutedMsg(message_id=95981, order=(Agent 1 @ 1970-01-01 04:22:04) : MKT Order ASK 28 AAPL)),
#  (1,
#   OrderCancelledMsg(message_id=95982, order=(Agent 1 @ 1970-01-01 04:21:10) : ASK 122 AAPL @ $195.01)),
#  (1,
#   OrderAcceptedMsg(message_id=95983, order=(Agent 1 @ 1970-01-01 04:22:04) : ASK 150 AAPL @ $195.01)),
#  (1,
#   OrderAcceptedMsg(message_id=95984, order=(Agent 1 @ 1970-01-01 04:22:09) : ASK 40 AAPL @ $189.00)),
#  (1,
#   OrderCancelledMsg(message_id=95985, order=(Agent 1 @ 1970-01-01 04:21:03) : ASK 100 AAPL @ $191.69)),
#  ...]

# %%
nasdaq_agent.messages[-1][1].order.quantity
# Out:
# 85

# %%
nasdaq_agent.messages[-2][1].order.quantity
# Out:
# 100
